# %% [markdown]
# # Branch and bound

# %% [markdown]
# ## [Michel Bierlaire](https://people.epfl.ch/michel.bierlaire), EPFL.

# %%
import numpy as np

# %% [markdown]
# We illustrate here the branch and bound algorithm on the traveling salesman problem. Note that we do not rely on mathematical modeling. We simply exploit the structure of the problem to calculate bounds.

# %% [markdown]
# This is Algorithm 26.1 in <a href="http://optimizationprinciplesalgorithms.com/">Bierlaire (2015) Optimization: principles and algorithms, EPFL Press.</a>

# %% [markdown]
# # Traveling salesman problem

# %% [markdown]
# The following class implements the symmetric traveling salesman problem. It takes as input the distance between every pair of two cities. In particular, it allows to calculate tour lengths, lower bounds, and tour extension. These are the problem specific ingredients that are needed by the branch and bound algorithm.

# %% [markdown]
# ## Lower bound calculation

# %% [markdown]
# The
# calculation of the lower bound can be done using the following
# reasoning. Each city in the tour involves two different arcs, one to reach the
# city, and one to leave it. A lower bound on the length of
# the two arcs incident to a city is obtained by considering the two
# shortest arcs incident to that city. If we compute this lower bound
# for all nodes and add them up, we have double counted each
# arc (once for each of the two incident cities). Therefore, a lower
# bound on the total path is obtained by dividing this quantity by two.

# %% [markdown]
# Note that the method described in this document is designed to illustrate the branch and bound algorithm. These lower bounds are quite poor, and this is not an efficient way to solve the problem.

# %%
class TSP:
    """
    Data management
    """
    def __init__(self, home, distances):
        self.distances = distances
        self.cities = set([c for k in self.distances.keys() for c in k])
        self.home = home
        if home not in self.cities:
            raise Exception(f'Home ({home}) does not belong to the list of cities: {self.cities}')
    def distance(self, c1, c2):    
        if (c1, c2) in self.distances:
            return self.distances[(c1, c2)]
        elif (c2, c1) in self.distances:
            return self.distances[(c2, c1)]
        else:
            raise Exception(f'Unknown pair of cities: {c1}-{c2}')
            
    def _contributionToLowerBound(self, city, fixed):
        if len(fixed) > 2:
            raise Exception(f'A maximum of two cities can be fixed: {fixed}')
        if city in fixed:
            raise Exception(f'City {city} cannot be in the list of fixed cities: {fixed}')
            
        # First calculate the distance from city to all other cities, excluding those that are fixed.
        allValues = [self.distance(city, i) for i in self.cities - set([city]) - set(fixed)]
        allValues.sort()
        if fixed:
            # The contributions to the lower bound combines fixed cities, and 
            values = [self.distance(city, i) for i in fixed] + allValues[:2-len(fixed)]
        else:
            values = allValues[:2]
        return sum(values)
    
    def tourLength(self, tour):
        if len(tour) != len(self.cities):
            raise Exception(f'This is not a valid tour. It covers {len(tour)} cities and not {len(self.cities)}')
        pairs = [(tour[i], tour[i + 1]) for i in range(len(tour) - 1)] + [(tour[-1], tour[0])]
        d = [self.distance(c1, c2) for (c1, c2) in pairs]
        return sum(d)
        
    def lowerBound(self, partialTour):
        # If all cities are involved, the tour is complete and the lower bound is the length of the tour.
        if len(partialTour) == len(self.cities):
            return self.tourLength(partialTour)
        
        fixedPairs = [(city, partialTour[i + 1]) for i, city in enumerate(partialTour[:-1])]
        fixedCities = {c: list() for c in self.cities}
        for c1, c2 in fixedPairs:
            fixedCities[c1].append(c2)
            fixedCities[c2].append(c1)
        bounds = [self._contributionToLowerBound(c, fixedCities[c]) for c in self.cities]
        return sum(bounds) / 2.0
    
    def extendTour(self, partialTour):
        if len(partialTour) == len(self.cities):
            raise Exception(f'Tour is already complete, Cannot be extended: {partialTour}')
        nonVisitedCities = self.cities - set(partialTour)
        newTours = [partialTour + [c] for c in nonVisitedCities]
        return newTours

# %% [markdown]
# # Subproblem

# %% [markdown]
# The branch and bound algorithm maintains a list of subproblems. The following class implements a subproblem. The key function is the "solve" function. It solves the problem to optimality if it is easy to do so, either because the problem itself is easy (typically, because only one city needs to be inserted), or because all the subproblems have been solved or discarded.

# %%
class subproblem:
    def __init__(self, tsp, partialTour):
        self.tsp = tsp
        self.partialTour = partialTour
        self.branches = None
        self.lowerBound = self.tsp.lowerBound(self.partialTour)
        self.optimalValue = None
        self.optimalTour = None
        self.subproblems = None

        
    def __str__(self):
        if self.optimalValue is not None: 
            return f'{self.partialTour} (Opt: {self.optimalValue})'
        elif self.lowerBound is not None:
            return f'{self.partialTour} [LB: {self.lowerBound}]'
        else:
            return f'{self.partialTour}'
            
    def isFeasible(self):
        # For TSP, all subproblems are feasible
        return True
    
    def calculateLowerBound(self):
        self.lowerBound = self.tsp.lowerBound(self.partialTour)
        return self.lowerBound
    
    def solve(self):
        # This function solves the problem is it is easy to do so, and returns False otherwise.
        # It also creates the branches, that is the subproblems.
        
        # If all the cities have been included, except one, the problem is trivial to solve.
        if len(self.partialTour) == len(self.tsp.cities) - 1:
            extendedTour = self.tsp.extendTour(self.partialTour)
            self.optimalTour = extendedTour[0]
            self.optimalValue = self.tsp.tourLength(self.optimalTour)
            return True
        
        # If no subproblem has been created, we create them
        if self.subproblems is None:
            extendedTours = self.tsp.extendTour(self.partialTour)
            self.subproblems = [subproblem(self.tsp, pt) for pt in extendedTours]
            return False
        
        bestTour = None
        bestValue = np.inf
        # We loop on the subproblems. If they have all been solved, the best solutiom
        # is the optimal solution of the current subproblem. 
        # If the optimal value is np.inf, it means that the problem has been discarded. 
        for p in self.subproblems: 
            if p.optimalValue is None:
                # The problem has not been treated. No way to solve the subproblem.
                return False
            else:
                if p.optimalValue < bestValue:
                    bestValue = p.optimalValue
                    bestTour = p.optimalTour
        self.optimalValue = bestValue
        self.optimalTour = bestTour
        return True

# %% [markdown]
# # Branch & bound

# %% [markdown]
# This is the branch and bound algorithm for the symmetric TSP problem.

# %%
def branchAndBound(tsp, firstTour=None):
    if firstTour is None:
        currentBestTour = [tsp.home] + [c for c in set(tsp.cities) - set([tsp.home])]
    else:
        currentBestTour = firstTour
    upperBound = tsp.tourLength(currentBestTour)
    fullProblem = subproblem(tsp,[tsp.home])
    setOfProblems = [fullProblem]
    iter = 0
    while setOfProblems:
        iter += 1
        currentProblem = setOfProblems[-1]
        if currentProblem.optimalValue == np.inf:
            setOfProblems.pop()
        else:
            print(f'======= Iteration {iter} =======')
            print(f'Current best tour: {currentBestTour} Length: {upperBound}')
            print(f'Treat problem {currentProblem}')
            lb = currentProblem.calculateLowerBound()
            if currentProblem.solve():
                if currentProblem.optimalValue < upperBound:
                    currentBestTour = currentProblem.optimalTour
                    upperBound = currentProblem.optimalValue
                # Remove the subproblem from the list
                print(f'--> Optimal solution of {currentProblem}: {currentProblem.optimalTour}')
                setOfProblems.pop()
            else:
                print(f'--> Branch')
                setOfProblems += currentProblem.subproblems
            msg = [f'\t{p.__str__()}' for p in setOfProblems if p.optimalValue != np.inf]
            if len(msg) == 0:
                print('No more problem to treat.')
            else:
                print('List of problems to treat:')
                print('\n'.join(msg))

            # Discard problems with a lower bound 
            # worse than the current upperbound
            for p in setOfProblems:
                if p.optimalValue != np.inf and p.lowerBound >= upperBound:
                    print(f'Discard {p} because lb={p.lowerBound} >= {upperBound}')
                    p.optimalValue = np.inf
    return fullProblem

# %% [markdown]
# # Example 1 - 4 cities

# %%
distances = {('L', 'G'): 64,
            ('L', 'B'): 104,
            ('L', 'Z'): 228,
            ('G', 'B'): 158,
            ('G', 'Z'): 279,
            ('B', 'Z'): 125}
tsp = TSP('L', distances)

# %%
fullProblem = branchAndBound(tsp,['L', 'Z', 'B', 'G'])
# Out:
# ======= Iteration 1 =======
# Current best tour: ['L', 'Z', 'B', 'G'] Length: 575
# Treat problem ['L'] [LB: 486.0]
# --> Branch
# List of problems to treat:
# 	['L'] [LB: 486.0]
# 	['L', 'Z'] [LB: 548.0]
# 	['L', 'G'] [LB: 486.0]
# 	['L', 'B'] [LB: 486.0]
# ======= Iteration 2 =======
# Current best tour: ['L', 'Z', 'B', 'G'] Length: 575
# Treat problem ['L', 'B'] [LB: 486.0]
# --> Branch
# List of problems to treat:
# 	['L'] [LB: 486.0]
# 	['L', 'Z'] [LB: 548.0]
# 	['L', 'G'] [LB: 486.0]
# 	['L', 'B'] [LB: 486.0]
# 	['L', 'B', 'Z'] [LB: 486.0]
# 	['L', 'B', 'G'] [LB: 502.5]
# ======= Iteration 3 =======
# Current best tour: ['L', 'Z', 'B', 'G'] Length: 575
# Treat problem ['L', 'B', 'G'] [LB: 502.5]
# --> Optimal solution of ['L', 'B', 'G'] (Opt: 769): ['L', 'B', 'G', 'Z']
# List of problems to treat:
# 	['L'] [LB: 486.0]
# 	['L', 'Z'] [LB: 548.0]
# 	['L', 'G'] [LB: 486.0]
# 	['L', 'B'] [LB: 486.0]
# 	['L', 'B', 'Z'] [LB: 486.0]
# ======= Iteration 4 =======
# Current best tour: ['L', 'Z', 'B', 'G'] Length: 575
# Treat problem ['L', 'B', 'Z'] [LB: 486.0]
# --> Optimal solution of ['L', 'B', 'Z'] (Opt: 572): ['L', 'B', 'Z', 'G']
# List of problems to treat:
# 	['L'] [LB: 486.0]
# 	['L', 'Z'] [LB: 548.0]
# 	['L', 'G'] [LB: 486.0]
# 	['L', 'B'] [LB: 486.0]
# ======= Iteration 5 =======
# Current best tour: ['L', 'B', 'Z', 'G'] Length: 572
# Treat problem ['L', 'B'] [LB: 486.0]
# --> Optimal solution of ['L', 'B'] (Opt: 572): ['L', 'B', 'Z', 'G']
# List of problems to treat:
# 	['L'] [LB: 486.0]
# 	['L', 'Z'] [LB: 548.0]
# 	['L', 'G'] [LB: 486.0]
# ======= Iteration 6 =======
# Current best tour: ['L', 'B', 'Z', 'G'] Length: 572
# Treat problem ['L', 'G'] [LB: 486.0]
# --> Branch
# List of problems to treat:
# 	['L'] [LB: 486.0]
# 	['L', 'Z'] [LB: 548.0]
# 	['L', 'G'] [LB: 486.0]
# 	['L', 'G', 'Z'] [LB: 572.0]
# 	['L', 'G', 'B'] [LB: 502.5]
# Discard ['L', 'G', 'Z'] [LB: 572.0] because lb=572.0 >= 572
# ======= Iteration 7 =======
# Current best tour: ['L', 'B', 'Z', 'G'] Length: 572
# Treat problem ['L', 'G', 'B'] [LB: 502.5]
# --> Optimal solution of ['L', 'G', 'B'] (Opt: 575): ['L', 'G', 'B', 'Z']
# List of problems to treat:
# 	['L'] [LB: 486.0]
# 	['L', 'Z'] [LB: 548.0]
# 	['L', 'G'] [LB: 486.0]
# ======= Iteration 9 =======
# Current best tour: ['L', 'B', 'Z', 'G'] Length: 572
# Treat problem ['L', 'G'] [LB: 486.0]
# --> Optimal solution of ['L', 'G'] (Opt: 575): ['L', 'G', 'B', 'Z']
# List of problems to treat:
# 	['L'] [LB: 486.0]
# 	['L', 'Z'] [LB: 548.0]
# ======= Iteration 10 =======
# Current best tour: ['L', 'B', 'Z', 'G'] Length: 572
# Treat problem ['L', 'Z'] [LB: 548.0]
# --> Branch
# List of problems to treat:
# 	['L'] [LB: 486.0]
# 	['L', 'Z'] [LB: 548.0]
# 	['L', 'Z', 'G'] [LB: 685.5]
# 	['L', 'Z', 'B'] [LB: 548.0]
# Discard ['L', 'Z', 'G'] [LB: 685.5] because lb=685.5 >= 572
# ======= Iteration 11 =======
# Current best tour: ['L', 'B', 'Z', 'G'] Length: 572
# Treat problem ['L', 'Z', 'B'] [LB: 548.0]
# --> Optimal solution of ['L', 'Z', 'B'] (Opt: 575): ['L', 'Z', 'B', 'G']
# List of problems to treat:
# 	['L'] [LB: 486.0]
# 	['L', 'Z'] [LB: 548.0]
# ======= Iteration 13 =======
# Current best tour: ['L', 'B', 'Z', 'G'] Length: 572
# Treat problem ['L', 'Z'] [LB: 548.0]
# --> Optimal solution of ['L', 'Z'] (Opt: 575): ['L', 'Z', 'B', 'G']
# List of problems to treat:
# 	['L'] [LB: 486.0]
# ======= Iteration 14 =======
# Current best tour: ['L', 'B', 'Z', 'G'] Length: 572
# Treat problem ['L'] [LB: 486.0]
# --> Optimal solution of ['L'] (Opt: 572): ['L', 'B', 'Z', 'G']
# No more problem to treat.

# %%
print(f'Optimal tour: {fullProblem.optimalTour}')
print(f'Length of the optimal tour: {fullProblem.optimalValue}')
# Out:
# Optimal tour: ['L', 'B', 'Z', 'G']
# Length of the optimal tour: 572

# %% [markdown]
# # Example 2 - 4 cities

# %%
distances = {('1', '2'): 10,
            ('1', '3'): 15,
            ('1', '4'): 20,
            ('2', '3'): 35,
            ('2', '4'): 25,
            ('3', '4'): 30}
tsp = TSP('1', distances)

# %%
fullProblem = branchAndBound(tsp)
# Out:
# ======= Iteration 1 =======
# Current best tour: ['1', '3', '4', '2'] Length: 80
# Treat problem ['1'] [LB: 75.0]
# --> Branch
# List of problems to treat:
# 	['1'] [LB: 75.0]
# 	['1', '3'] [LB: 75.0]
# 	['1', '4'] [LB: 77.5]
# 	['1', '2'] [LB: 75.0]
# ======= Iteration 2 =======
# Current best tour: ['1', '3', '4', '2'] Length: 80
# Treat problem ['1', '2'] [LB: 75.0]
# --> Branch
# List of problems to treat:
# 	['1'] [LB: 75.0]
# 	['1', '3'] [LB: 75.0]
# 	['1', '4'] [LB: 77.5]
# 	['1', '2'] [LB: 75.0]
# 	['1', '2', '3'] [LB: 82.5]
# 	['1', '2', '4'] [LB: 75.0]
# Discard ['1', '2', '3'] [LB: 82.5] because lb=82.5 >= 80
# ======= Iteration 3 =======
# Current best tour: ['1', '3', '4', '2'] Length: 80
# Treat problem ['1', '2', '4'] [LB: 75.0]
# --> Optimal solution of ['1', '2', '4'] (Opt: 80): ['1', '2', '4', '3']
# List of problems to treat:
# 	['1'] [LB: 75.0]
# 	['1', '3'] [LB: 75.0]
# 	['1', '4'] [LB: 77.5]
# 	['1', '2'] [LB: 75.0]
# ======= Iteration 5 =======
# Current best tour: ['1', '3', '4', '2'] Length: 80
# Treat problem ['1', '2'] [LB: 75.0]
# --> Optimal solution of ['1', '2'] (Opt: 80): ['1', '2', '4', '3']
# List of problems to treat:
# 	['1'] [LB: 75.0]
# 	['1', '3'] [LB: 75.0]
# 	['1', '4'] [LB: 77.5]
# ======= Iteration 6 =======
# Current best tour: ['1', '3', '4', '2'] Length: 80
# Treat problem ['1', '4'] [LB: 77.5]
# --> Branch
# List of problems to treat:
# 	['1'] [LB: 75.0]
# 	['1', '3'] [LB: 75.0]
# 	['1', '4'] [LB: 77.5]
# 	['1', '4', '3'] [LB: 80.0]
# 	['1', '4', '2'] [LB: 77.5]
# Discard ['1', '4', '3'] [LB: 80.0] because lb=80.0 >= 80
# ======= Iteration 7 =======
# Current best tour: ['1', '3', '4', '2'] Length: 80
# Treat problem ['1', '4', '2'] [LB: 77.5]
# --> Optimal solution of ['1', '4', '2'] (Opt: 95): ['1', '4', '2', '3']
# List of problems to treat:
# 	['1'] [LB: 75.0]
# 	['1', '3'] [LB: 75.0]
# 	['1', '4'] [LB: 77.5]
# ======= Iteration 9 =======
# Current best tour: ['1', '3', '4', '2'] Length: 80
# Treat problem ['1', '4'] [LB: 77.5]
# --> Optimal solution of ['1', '4'] (Opt: 95): ['1', '4', '2', '3']
# List of problems to treat:
# 	['1'] [LB: 75.0]
# 	['1', '3'] [LB: 75.0]
# ======= Iteration 10 =======
# Current best tour: ['1', '3', '4', '2'] Length: 80
# Treat problem ['1', '3'] [LB: 75.0]
# --> Branch
# List of problems to treat:
# 	['1'] [LB: 75.0]
# 	['1', '3'] [LB: 75.0]
# 	['1', '3', '4'] [LB: 77.5]
# 	['1', '3', '2'] [LB: 82.5]
# Discard ['1', '3', '2'] [LB: 82.5] because lb=82.5 >= 80
# ======= Iteration 12 =======
# Current best tour: ['1', '3', '4', '2'] Length: 80
# Treat problem ['1', '3', '4'] [LB: 77.5]
# --> Optimal solution of ['1', '3', '4'] (Opt: 80): ['1', '3', '4', '2']
# List of problems to treat:
# 	['1'] [LB: 75.0]
# 	['1', '3'] [LB: 75.0]
# ======= Iteration 13 =======
# Current best tour: ['1', '3', '4', '2'] Length: 80
# Treat problem ['1', '3'] [LB: 75.0]
# --> Optimal solution of ['1', '3'] (Opt: 80): ['1', '3', '4', '2']
# List of problems to treat:
# 	['1'] [LB: 75.0]
# ======= Iteration 14 =======
# Current best tour: ['1', '3', '4', '2'] Length: 80
# Treat problem ['1'] [LB: 75.0]
# --> Optimal solution of ['1'] (Opt: 80): ['1', '3', '4', '2']
# No more problem to treat.

# %%
print(f'Optimal tour: {fullProblem.optimalTour}')
print(f'Length of the optimal tour: {fullProblem.optimalValue}')
# Out:
# Optimal tour: ['1', '3', '4', '2']
# Length of the optimal tour: 80

# %% [markdown]
# # Example 3 - 5 cities

# %%
distances = {('A', 'B'): 100,
            ('A', 'C'): 300,
            ('A', 'D'): 100,
            ('A', 'E'): 75,
            ('B', 'C'): 50,
            ('B', 'D'): 75,
            ('B', 'E'): 125,
            ('C', 'D'): 100,
            ('C', 'E'): 125,
            ('D', 'E'): 50}
tsp = TSP('E', distances)

# %%
fullProblem = branchAndBound(tsp)
# Out:
# ======= Iteration 1 =======
# Current best tour: ['E', 'A', 'C', 'B', 'D'] Length: 550
# Treat problem ['E'] [LB: 350.0]
# --> Branch
# List of problems to treat:
# 	['E'] [LB: 350.0]
# 	['E', 'A'] [LB: 350.0]
# 	['E', 'C'] [LB: 387.5]
# 	['E', 'B'] [LB: 400.0]
# 	['E', 'D'] [LB: 350.0]
# ======= Iteration 2 =======
# Current best tour: ['E', 'A', 'C', 'B', 'D'] Length: 550
# Treat problem ['E', 'D'] [LB: 350.0]
# --> Branch
# List of problems to treat:
# 	['E'] [LB: 350.0]
# 	['E', 'A'] [LB: 350.0]
# 	['E', 'C'] [LB: 387.5]
# 	['E', 'B'] [LB: 400.0]
# 	['E', 'D'] [LB: 350.0]
# 	['E', 'D', 'A'] [LB: 362.5]
# 	['E', 'D', 'B'] [LB: 350.0]
# 	['E', 'D', 'C'] [LB: 362.5]
# ======= Iteration 3 =======
# Current best tour: ['E', 'A', 'C', 'B', 'D'] Length: 550
# Treat problem ['E', 'D', 'C'] [LB: 362.5]
# --> Branch
# List of problems to treat:
# 	['E'] [LB: 350.0]
# 	['E', 'A'] [LB: 350.0]
# 	['E', 'C'] [LB: 387.5]
# 	['E', 'B'] [LB: 400.0]
# 	['E', 'D'] [LB: 350.0]
# 	['E', 'D', 'A'] [LB: 362.5]
# 	['E', 'D', 'B'] [LB: 350.0]
# 	['E', 'D', 'C'] [LB: 362.5]
# 	['E', 'D', 'C', 'A'] [LB: 587.5]
# 	['E', 'D', 'C', 'B'] [LB: 362.5]
# Discard ['E', 'D', 'C', 'A'] [LB: 587.5] because lb=587.5 >= 550
# ======= Iteration 4 =======
# Current best tour: ['E', 'A', 'C', 'B', 'D'] Length: 550
# Treat problem ['E', 'D', 'C', 'B'] [LB: 362.5]
# --> Optimal solution of ['E', 'D', 'C', 'B'] (Opt: 375): ['E', 'D', 'C', 'B', 'A']
# List of problems to treat:
# 	['E'] [LB: 350.0]
# 	['E', 'A'] [LB: 350.0]
# 	['E', 'C'] [LB: 387.5]
# 	['E', 'B'] [LB: 400.0]
# 	['E', 'D'] [LB: 350.0]
# 	['E', 'D', 'A'] [LB: 362.5]
# 	['E', 'D', 'B'] [LB: 350.0]
# 	['E', 'D', 'C'] [LB: 362.5]
# Discard ['E', 'C'] [LB: 387.5] because lb=387.5 >= 375
# Discard ['E', 'B'] [LB: 400.0] because lb=400.0 >= 375
# ======= Iteration 6 =======
# Current best tour: ['E', 'D', 'C', 'B', 'A'] Length: 375
# Treat problem ['E', 'D', 'C'] [LB: 362.5]
# --> Optimal solution of ['E', 'D', 'C'] (Opt: 375): ['E', 'D', 'C', 'B', 'A']
# List of problems to treat:
# 	['E'] [LB: 350.0]
# 	['E', 'A'] [LB: 350.0]
# 	['E', 'D'] [LB: 350.0]
# 	['E', 'D', 'A'] [LB: 362.5]
# 	['E', 'D', 'B'] [LB: 350.0]
# ======= Iteration 7 =======
# Current best tour: ['E', 'D', 'C', 'B', 'A'] Length: 375
# Treat problem ['E', 'D', 'B'] [LB: 350.0]
# --> Branch
# List of problems to treat:
# 	['E'] [LB: 350.0]
# 	['E', 'A'] [LB: 350.0]
# 	['E', 'D'] [LB: 350.0]
# 	['E', 'D', 'A'] [LB: 362.5]
# 	['E', 'D', 'B'] [LB: 350.0]
# 	['E', 'D', 'B', 'A'] [LB: 375.0]
# 	['E', 'D', 'B', 'C'] [LB: 350.0]
# Discard ['E', 'D', 'B', 'A'] [LB: 375.0] because lb=375.0 >= 375
# ======= Iteration 8 =======
# Current best tour: ['E', 'D', 'C', 'B', 'A'] Length: 375
# Treat problem ['E', 'D', 'B', 'C'] [LB: 350.0]
# --> Optimal solution of ['E', 'D', 'B', 'C'] (Opt: 550): ['E', 'D', 'B', 'C', 'A']
# List of problems to treat:
# 	['E'] [LB: 350.0]
# 	['E', 'A'] [LB: 350.0]
# 	['E', 'D'] [LB: 350.0]
# 	['E', 'D', 'A'] [LB: 362.5]
# 	['E', 'D', 'B'] [LB: 350.0]
# ======= Iteration 10 =======
# Current best tour: ['E', 'D', 'C', 'B', 'A'] Length: 375
# Treat problem ['E', 'D', 'B'] [LB: 350.0]
# --> Optimal solution of ['E', 'D', 'B'] (Opt: 550): ['E', 'D', 'B', 'C', 'A']
# List of problems to treat:
# 	['E'] [LB: 350.0]
# 	['E', 'A'] [LB: 350.0]
# 	['E', 'D'] [LB: 350.0]
# 	['E', 'D', 'A'] [LB: 362.5]
# ======= Iteration 11 =======
# Current best tour: ['E', 'D', 'C', 'B', 'A'] Length: 375
# Treat problem ['E', 'D', 'A'] [LB: 362.5]
# --> Branch
# List of problems to treat:
# 	['E'] [LB: 350.0]
# 	['E', 'A'] [LB: 350.0]
# 	['E', 'D'] [LB: 350.0]
# 	['E', 'D', 'A'] [LB: 362.5]
# 	['E', 'D', 'A', 'B'] [LB: 387.5]
# 	['E', 'D', 'A', 'C'] [LB: 575.0]
# Discard ['E', 'D', 'A', 'B'] [LB: 387.5] because lb=387.5 >= 375
# Discard ['E', 'D', 'A', 'C'] [LB: 575.0] because lb=575.0 >= 375
# ======= Iteration 14 =======
# Current best tour: ['E', 'D', 'C', 'B', 'A'] Length: 375
# Treat problem ['E', 'D', 'A'] [LB: 362.5]
# --> Optimal solution of ['E', 'D', 'A'] (Opt: inf): None
# List of problems to treat:
# 	['E'] [LB: 350.0]
# 	['E', 'A'] [LB: 350.0]
# 	['E', 'D'] [LB: 350.0]
# ======= Iteration 15 =======
# Current best tour: ['E', 'D', 'C', 'B', 'A'] Length: 375
# Treat problem ['E', 'D'] [LB: 350.0]
# --> Optimal solution of ['E', 'D'] (Opt: 375): ['E', 'D', 'C', 'B', 'A']
# List of problems to treat:
# 	['E'] [LB: 350.0]
# 	['E', 'A'] [LB: 350.0]
# ======= Iteration 18 =======
# Current best tour: ['E', 'D', 'C', 'B', 'A'] Length: 375
# Treat problem ['E', 'A'] [LB: 350.0]
# --> Branch
# List of problems to treat:
# 	['E'] [LB: 350.0]
# 	['E', 'A'] [LB: 350.0]
# 	['E', 'A', 'C'] [LB: 550.0]
# 	['E', 'A', 'B'] [LB: 362.5]
# 	['E', 'A', 'D'] [LB: 362.5]
# Discard ['E', 'A', 'C'] [LB: 550.0] because lb=550.0 >= 375
# ======= Iteration 19 =======
# Current best tour: ['E', 'D', 'C', 'B', 'A'] Length: 375
# Treat problem ['E', 'A', 'D'] [LB: 362.5]
# --> Branch
# List of problems to treat:
# 	['E'] [LB: 350.0]
# 	['E', 'A'] [LB: 350.0]
# 	['E', 'A', 'B'] [LB: 362.5]
# 	['E', 'A', 'D'] [LB: 362.5]
# 	['E', 'A', 'D', 'B'] [LB: 375.0]
# 	['E', 'A', 'D', 'C'] [LB: 387.5]
# Discard ['E', 'A', 'D', 'B'] [LB: 375.0] because lb=375.0 >= 375
# Discard ['E', 'A', 'D', 'C'] [LB: 387.5] because lb=387.5 >= 375
# ======= Iteration 22 =======
# Current best tour: ['E', 'D', 'C', 'B', 'A'] Length: 375
# Treat problem ['E', 'A', 'D'] [LB: 362.5]
# --> Optimal solution of ['E', 'A', 'D'] (Opt: inf): None
# List of problems to treat:
# 	['E'] [LB: 350.0]
# 	['E', 'A'] [LB: 350.0]
# 	['E', 'A', 'B'] [LB: 362.5]
# ======= Iteration 23 =======
# Current best tour: ['E', 'D', 'C', 'B', 'A'] Length: 375
# Treat problem ['E', 'A', 'B'] [LB: 362.5]
# --> Branch
# List of problems to treat:
# 	['E'] [LB: 350.0]
# 	['E', 'A'] [LB: 350.0]
# 	['E', 'A', 'B'] [LB: 362.5]
# 	['E', 'A', 'B', 'D'] [LB: 375.0]
# 	['E', 'A', 'B', 'C'] [LB: 362.5]
# Discard ['E', 'A', 'B', 'D'] [LB: 375.0] because lb=375.0 >= 375
# ======= Iteration 24 =======
# Current best tour: ['E', 'D', 'C', 'B', 'A'] Length: 375
# Treat problem ['E', 'A', 'B', 'C'] [LB: 362.5]
# --> Optimal solution of ['E', 'A', 'B', 'C'] (Opt: 375): ['E', 'A', 'B', 'C', 'D']
# List of problems to treat:
# 	['E'] [LB: 350.0]
# 	['E', 'A'] [LB: 350.0]
# 	['E', 'A', 'B'] [LB: 362.5]
# ======= Iteration 26 =======
# Current best tour: ['E', 'D', 'C', 'B', 'A'] Length: 375
# Treat problem ['E', 'A', 'B'] [LB: 362.5]
# --> Optimal solution of ['E', 'A', 'B'] (Opt: 375): ['E', 'A', 'B', 'C', 'D']
# List of problems to treat:
# 	['E'] [LB: 350.0]
# 	['E', 'A'] [LB: 350.0]
# ======= Iteration 28 =======
# Current best tour: ['E', 'D', 'C', 'B', 'A'] Length: 375
# Treat problem ['E', 'A'] [LB: 350.0]
# --> Optimal solution of ['E', 'A'] (Opt: 375): ['E', 'A', 'B', 'C', 'D']
# List of problems to treat:
# 	['E'] [LB: 350.0]
# ======= Iteration 29 =======
# Current best tour: ['E', 'D', 'C', 'B', 'A'] Length: 375
# Treat problem ['E'] [LB: 350.0]
# --> Optimal solution of ['E'] (Opt: 375): ['E', 'A', 'B', 'C', 'D']
# No more problem to treat.

# %%
print(f'Optimal tour: {fullProblem.optimalTour}')
print(f'Length of the optimal tour: {fullProblem.optimalValue}')
# Out:
# Optimal tour: ['E', 'A', 'B', 'C', 'D']
# Length of the optimal tour: 375

# %% [markdown]
# We run the algorithm again, starting with the optimal solution. We observe that it may take a while for the algorithm to realize that it is indeed the optimal solution.

# %%
fullProblem = branchAndBound(tsp,['E', 'A', 'B', 'C', 'D'])
# Out:
# ======= Iteration 1 =======
# Current best tour: ['E', 'A', 'B', 'C', 'D'] Length: 375
# Treat problem ['E'] [LB: 350.0]
# --> Branch
# List of problems to treat:
# 	['E'] [LB: 350.0]
# 	['E', 'A'] [LB: 350.0]
# 	['E', 'C'] [LB: 387.5]
# 	['E', 'B'] [LB: 400.0]
# 	['E', 'D'] [LB: 350.0]
# Discard ['E', 'C'] [LB: 387.5] because lb=387.5 >= 375
# Discard ['E', 'B'] [LB: 400.0] because lb=400.0 >= 375
# ======= Iteration 2 =======
# Current best tour: ['E', 'A', 'B', 'C', 'D'] Length: 375
# Treat problem ['E', 'D'] [LB: 350.0]
# --> Branch
# List of problems to treat:
# 	['E'] [LB: 350.0]
# 	['E', 'A'] [LB: 350.0]
# 	['E', 'D'] [LB: 350.0]
# 	['E', 'D', 'A'] [LB: 362.5]
# 	['E', 'D', 'B'] [LB: 350.0]
# 	['E', 'D', 'C'] [LB: 362.5]
# ======= Iteration 3 =======
# Current best tour: ['E', 'A', 'B', 'C', 'D'] Length: 375
# Treat problem ['E', 'D', 'C'] [LB: 362.5]
# --> Branch
# List of problems to treat:
# 	['E'] [LB: 350.0]
# 	['E', 'A'] [LB: 350.0]
# 	['E', 'D'] [LB: 350.0]
# 	['E', 'D', 'A'] [LB: 362.5]
# 	['E', 'D', 'B'] [LB: 350.0]
# 	['E', 'D', 'C'] [LB: 362.5]
# 	['E', 'D', 'C', 'A'] [LB: 587.5]
# 	['E', 'D', 'C', 'B'] [LB: 362.5]
# Discard ['E', 'D', 'C', 'A'] [LB: 587.5] because lb=587.5 >= 375
# ======= Iteration 4 =======
# Current best tour: ['E', 'A', 'B', 'C', 'D'] Length: 375
# Treat problem ['E', 'D', 'C', 'B'] [LB: 362.5]
# --> Optimal solution of ['E', 'D', 'C', 'B'] (Opt: 375): ['E', 'D', 'C', 'B', 'A']
# List of problems to treat:
# 	['E'] [LB: 350.0]
# 	['E', 'A'] [LB: 350.0]
# 	['E', 'D'] [LB: 350.0]
# 	['E', 'D', 'A'] [LB: 362.5]
# 	['E', 'D', 'B'] [LB: 350.0]
# 	['E', 'D', 'C'] [LB: 362.5]
# ======= Iteration 6 =======
# Current best tour: ['E', 'A', 'B', 'C', 'D'] Length: 375
# Treat problem ['E', 'D', 'C'] [LB: 362.5]
# --> Optimal solution of ['E', 'D', 'C'] (Opt: 375): ['E', 'D', 'C', 'B', 'A']
# List of problems to treat:
# 	['E'] [LB: 350.0]
# 	['E', 'A'] [LB: 350.0]
# 	['E', 'D'] [LB: 350.0]
# 	['E', 'D', 'A'] [LB: 362.5]
# 	['E', 'D', 'B'] [LB: 350.0]
# ======= Iteration 7 =======
# Current best tour: ['E', 'A', 'B', 'C', 'D'] Length: 375
# Treat problem ['E', 'D', 'B'] [LB: 350.0]
# --> Branch
# List of problems to treat:
# 	['E'] [LB: 350.0]
# 	['E', 'A'] [LB: 350.0]
# 	['E', 'D'] [LB: 350.0]
# 	['E', 'D', 'A'] [LB: 362.5]
# 	['E', 'D', 'B'] [LB: 350.0]
# 	['E', 'D', 'B', 'A'] [LB: 375.0]
# 	['E', 'D', 'B', 'C'] [LB: 350.0]
# Discard ['E', 'D', 'B', 'A'] [LB: 375.0] because lb=375.0 >= 375
# ======= Iteration 8 =======
# Current best tour: ['E', 'A', 'B', 'C', 'D'] Length: 375
# Treat problem ['E', 'D', 'B', 'C'] [LB: 350.0]
# --> Optimal solution of ['E', 'D', 'B', 'C'] (Opt: 550): ['E', 'D', 'B', 'C', 'A']
# List of problems to treat:
# 	['E'] [LB: 350.0]
# 	['E', 'A'] [LB: 350.0]
# 	['E', 'D'] [LB: 350.0]
# 	['E', 'D', 'A'] [LB: 362.5]
# 	['E', 'D', 'B'] [LB: 350.0]
# ======= Iteration 10 =======
# Current best tour: ['E', 'A', 'B', 'C', 'D'] Length: 375
# Treat problem ['E', 'D', 'B'] [LB: 350.0]
# --> Optimal solution of ['E', 'D', 'B'] (Opt: 550): ['E', 'D', 'B', 'C', 'A']
# List of problems to treat:
# 	['E'] [LB: 350.0]
# 	['E', 'A'] [LB: 350.0]
# 	['E', 'D'] [LB: 350.0]
# 	['E', 'D', 'A'] [LB: 362.5]
# ======= Iteration 11 =======
# Current best tour: ['E', 'A', 'B', 'C', 'D'] Length: 375
# Treat problem ['E', 'D', 'A'] [LB: 362.5]
# --> Branch
# List of problems to treat:
# 	['E'] [LB: 350.0]
# 	['E', 'A'] [LB: 350.0]
# 	['E', 'D'] [LB: 350.0]
# 	['E', 'D', 'A'] [LB: 362.5]
# 	['E', 'D', 'A', 'B'] [LB: 387.5]
# 	['E', 'D', 'A', 'C'] [LB: 575.0]
# Discard ['E', 'D', 'A', 'B'] [LB: 387.5] because lb=387.5 >= 375
# Discard ['E', 'D', 'A', 'C'] [LB: 575.0] because lb=575.0 >= 375
# ======= Iteration 14 =======
# Current best tour: ['E', 'A', 'B', 'C', 'D'] Length: 375
# Treat problem ['E', 'D', 'A'] [LB: 362.5]
# --> Optimal solution of ['E', 'D', 'A'] (Opt: inf): None
# List of problems to treat:
# 	['E'] [LB: 350.0]
# 	['E', 'A'] [LB: 350.0]
# 	['E', 'D'] [LB: 350.0]
# ======= Iteration 15 =======
# Current best tour: ['E', 'A', 'B', 'C', 'D'] Length: 375
# Treat problem ['E', 'D'] [LB: 350.0]
# --> Optimal solution of ['E', 'D'] (Opt: 375): ['E', 'D', 'C', 'B', 'A']
# List of problems to treat:
# 	['E'] [LB: 350.0]
# 	['E', 'A'] [LB: 350.0]
# ======= Iteration 18 =======
# Current best tour: ['E', 'A', 'B', 'C', 'D'] Length: 375
# Treat problem ['E', 'A'] [LB: 350.0]
# --> Branch
# List of problems to treat:
# 	['E'] [LB: 350.0]
# 	['E', 'A'] [LB: 350.0]
# 	['E', 'A', 'C'] [LB: 550.0]
# 	['E', 'A', 'B'] [LB: 362.5]
# 	['E', 'A', 'D'] [LB: 362.5]
# Discard ['E', 'A', 'C'] [LB: 550.0] because lb=550.0 >= 375
# ======= Iteration 19 =======
# Current best tour: ['E', 'A', 'B', 'C', 'D'] Length: 375
# Treat problem ['E', 'A', 'D'] [LB: 362.5]
# --> Branch
# List of problems to treat:
# 	['E'] [LB: 350.0]
# 	['E', 'A'] [LB: 350.0]
# 	['E', 'A', 'B'] [LB: 362.5]
# 	['E', 'A', 'D'] [LB: 362.5]
# 	['E', 'A', 'D', 'B'] [LB: 375.0]
# 	['E', 'A', 'D', 'C'] [LB: 387.5]
# Discard ['E', 'A', 'D', 'B'] [LB: 375.0] because lb=375.0 >= 375
# Discard ['E', 'A', 'D', 'C'] [LB: 387.5] because lb=387.5 >= 375
# ======= Iteration 22 =======
# Current best tour: ['E', 'A', 'B', 'C', 'D'] Length: 375
# Treat problem ['E', 'A', 'D'] [LB: 362.5]
# --> Optimal solution of ['E', 'A', 'D'] (Opt: inf): None
# List of problems to treat:
# 	['E'] [LB: 350.0]
# 	['E', 'A'] [LB: 350.0]
# 	['E', 'A', 'B'] [LB: 362.5]
# ======= Iteration 23 =======
# Current best tour: ['E', 'A', 'B', 'C', 'D'] Length: 375
# Treat problem ['E', 'A', 'B'] [LB: 362.5]
# --> Branch
# List of problems to treat:
# 	['E'] [LB: 350.0]
# 	['E', 'A'] [LB: 350.0]
# 	['E', 'A', 'B'] [LB: 362.5]
# 	['E', 'A', 'B', 'D'] [LB: 375.0]
# 	['E', 'A', 'B', 'C'] [LB: 362.5]
# Discard ['E', 'A', 'B', 'D'] [LB: 375.0] because lb=375.0 >= 375
# ======= Iteration 24 =======
# Current best tour: ['E', 'A', 'B', 'C', 'D'] Length: 375
# Treat problem ['E', 'A', 'B', 'C'] [LB: 362.5]
# --> Optimal solution of ['E', 'A', 'B', 'C'] (Opt: 375): ['E', 'A', 'B', 'C', 'D']
# List of problems to treat:
# 	['E'] [LB: 350.0]
# 	['E', 'A'] [LB: 350.0]
# 	['E', 'A', 'B'] [LB: 362.5]
# ======= Iteration 26 =======
# Current best tour: ['E', 'A', 'B', 'C', 'D'] Length: 375
# Treat problem ['E', 'A', 'B'] [LB: 362.5]
# --> Optimal solution of ['E', 'A', 'B'] (Opt: 375): ['E', 'A', 'B', 'C', 'D']
# List of problems to treat:
# 	['E'] [LB: 350.0]
# 	['E', 'A'] [LB: 350.0]
# ======= Iteration 28 =======
# Current best tour: ['E', 'A', 'B', 'C', 'D'] Length: 375
# Treat problem ['E', 'A'] [LB: 350.0]
# --> Optimal solution of ['E', 'A'] (Opt: 375): ['E', 'A', 'B', 'C', 'D']
# List of problems to treat:
# 	['E'] [LB: 350.0]
# ======= Iteration 29 =======
# Current best tour: ['E', 'A', 'B', 'C', 'D'] Length: 375
# Treat problem ['E'] [LB: 350.0]
# --> Optimal solution of ['E'] (Opt: 375): ['E', 'A', 'B', 'C', 'D']
# No more problem to treat.

# %%
print(f'Optimal tour: {fullProblem.optimalTour}')
print(f'Length of the optimal tour: {fullProblem.optimalValue}')
# Out:
# Optimal tour: ['E', 'A', 'B', 'C', 'D']
# Length of the optimal tour: 375

# %% [markdown]
# # Random example

# %% [markdown]
# We considered $n$ cities whose coordinates are randomly generated.

# %%
import random as rnd
n = 6
x = [rnd.uniform(0, 10) for i in range(n)]
y = [rnd.uniform(0, 10) for i in range(n)]
names = [f'{i}' for i in range(1, n + 1)]

# %%
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots()
ax.scatter(x, y)
for i in range(n):
    ax.annotate(names[i], (x[i], y[i]))

# %% [markdown]
# And we consider the Euclidean distance between them.

# %%
distances = {(names[i], names[j]): 
             np.sqrt((x[i] - x[j]) * (x[i] - x[j]) + 
                     (y[i] - y[j]) * (y[i] - y[j])) 
             for i in range(n) for j in range(i + 1, n) }
tsp = TSP('1', distances)

# %%
fullProblem = branchAndBound(tsp)
# Out:
# ======= Iteration 1 =======
# Current best tour: ['1', '2', '5', '6', '4', '3'] Length: 27.487981870415688
# Treat problem ['1'] [LB: 17.215059123497515]
# --> Branch
# List of problems to treat:
# 	['1'] [LB: 17.215059123497515]
# 	['1', '2'] [LB: 17.314092579818546]
# 	['1', '5'] [LB: 21.0029496864565]
# 	['1', '6'] [LB: 18.593608197898767]
# 	['1', '4'] [LB: 21.495222661589793]
# 	['1', '3'] [LB: 17.935201547501446]
# ======= Iteration 2 =======
# Current best tour: ['1', '2', '5', '6', '4', '3'] Length: 27.487981870415688
# Treat problem ['1', '3'] [LB: 17.935201547501446]
# --> Branch
# List of problems to treat:
# 	['1'] [LB: 17.215059123497515]
# 	['1', '2'] [LB: 17.314092579818546]
# 	['1', '5'] [LB: 21.0029496864565]
# 	['1', '6'] [LB: 18.593608197898767]
# 	['1', '4'] [LB: 21.495222661589793]
# 	['1', '3'] [LB: 17.935201547501446]
# 	['1', '3', '6'] [LB: 18.480649565702137]
# 	['1', '3', '4'] [LB: 20.868955904693667]
# 	['1', '3', '5'] [LB: 21.577467692074123]
# 	['1', '3', '2'] [LB: 17.935201547501446]
# ======= Iteration 3 =======
# Current best tour: ['1', '2', '5', '6', '4', '3'] Length: 27.487981870415688
# Treat problem ['1', '3', '2'] [LB: 17.935201547501446]
# --> Branch
# List of problems to treat:
# 	['1'] [LB: 17.215059123497515]
# 	['1', '2'] [LB: 17.314092579818546]
# 	['1', '5'] [LB: 21.0029496864565]
# 	['1', '6'] [LB: 18.593608197898767]
# 	['1', '4'] [LB: 21.495222661589793]
# 	['1', '3'] [LB: 17.935201547501446]
# 	['1', '3', '6'] [LB: 18.480649565702137]
# 	['1', '3', '4'] [LB: 20.868955904693667]
# 	['1', '3', '5'] [LB: 21.577467692074123]
# 	['1', '3', '2'] [LB: 17.935201547501446]
# 	['1', '3', '2', '6'] [LB: 18.445455968746685]
# 	['1', '3', '2', '4'] [LB: 20.929167750749016]
# 	['1', '3', '2', '5'] [LB: 21.74910844141601]
# ======= Iteration 4 =======
# Current best tour: ['1', '2', '5', '6', '4', '3'] Length: 27.487981870415688
# Treat problem ['1', '3', '2', '5'] [LB: 21.74910844141601]
# --> Branch
# List of problems to treat:
# 	['1'] [LB: 17.215059123497515]
# 	['1', '2'] [LB: 17.314092579818546]
# 	['1', '5'] [LB: 21.0029496864565]
# 	['1', '6'] [LB: 18.593608197898767]
# 	['1', '4'] [LB: 21.495222661589793]
# 	['1', '3'] [LB: 17.935201547501446]
# 	['1', '3', '6'] [LB: 18.480649565702137]
# 	['1', '3', '4'] [LB: 20.868955904693667]
# 	['1', '3', '5'] [LB: 21.577467692074123]
# 	['1', '3', '2'] [LB: 17.935201547501446]
# 	['1', '3', '2', '6'] [LB: 18.445455968746685]
# 	['1', '3', '2', '4'] [LB: 20.929167750749016]
# 	['1', '3', '2', '5'] [LB: 21.74910844141601]
# 	['1', '3', '2', '5', '6'] [LB: 22.729075183665003]
# 	['1', '3', '2', '5', '4'] [LB: 21.74910844141601]
# ======= Iteration 5 =======
# Current best tour: ['1', '2', '5', '6', '4', '3'] Length: 27.487981870415688
# Treat problem ['1', '3', '2', '5', '4'] [LB: 21.74910844141601]
# --> Optimal solution of ['1', '3', '2', '5', '4'] (Opt: 23.334841219906476): ['1', '3', '2', '5', '4', '6']
# List of problems to treat:
# 	['1'] [LB: 17.215059123497515]
# 	['1', '2'] [LB: 17.314092579818546]
# 	['1', '5'] [LB: 21.0029496864565]
# 	['1', '6'] [LB: 18.593608197898767]
# 	['1', '4'] [LB: 21.495222661589793]
# 	['1', '3'] [LB: 17.935201547501446]
# 	['1', '3', '6'] [LB: 18.480649565702137]
# 	['1', '3', '4'] [LB: 20.868955904693667]
# 	['1', '3', '5'] [LB: 21.577467692074123]
# 	['1', '3', '2'] [LB: 17.935201547501446]
# 	['1', '3', '2', '6'] [LB: 18.445455968746685]
# 	['1', '3', '2', '4'] [LB: 20.929167750749016]
# 	['1', '3', '2', '5'] [LB: 21.74910844141601]
# 	['1', '3', '2', '5', '6'] [LB: 22.729075183665003]
# ======= Iteration 6 =======
# Current best tour: ['1', '3', '2', '5', '4', '6'] Length: 23.334841219906476
# Treat problem ['1', '3', '2', '5', '6'] [LB: 22.729075183665003]
# --> Optimal solution of ['1', '3', '2', '5', '6'] (Opt: 27.472471451459583): ['1', '3', '2', '5', '6', '4']
# List of problems to treat:
# 	['1'] [LB: 17.215059123497515]
# 	['1', '2'] [LB: 17.314092579818546]
# 	['1', '5'] [LB: 21.0029496864565]
# 	['1', '6'] [LB: 18.593608197898767]
# 	['1', '4'] [LB: 21.495222661589793]
# 	['1', '3'] [LB: 17.935201547501446]
# 	['1', '3', '6'] [LB: 18.480649565702137]
# 	['1', '3', '4'] [LB: 20.868955904693667]
# 	['1', '3', '5'] [LB: 21.577467692074123]
# 	['1', '3', '2'] [LB: 17.935201547501446]
# 	['1', '3', '2', '6'] [LB: 18.445455968746685]
# 	['1', '3', '2', '4'] [LB: 20.929167750749016]
# 	['1', '3', '2', '5'] [LB: 21.74910844141601]
# ======= Iteration 7 =======
# Current best tour: ['1', '3', '2', '5', '4', '6'] Length: 23.334841219906476
# Treat problem ['1', '3', '2', '5'] [LB: 21.74910844141601]
# --> Optimal solution of ['1', '3', '2', '5'] (Opt: 23.334841219906476): ['1', '3', '2', '5', '4', '6']
# List of problems to treat:
# 	['1'] [LB: 17.215059123497515]
# 	['1', '2'] [LB: 17.314092579818546]
# 	['1', '5'] [LB: 21.0029496864565]
# 	['1', '6'] [LB: 18.593608197898767]
# 	['1', '4'] [LB: 21.495222661589793]
# 	['1', '3'] [LB: 17.935201547501446]
# 	['1', '3', '6'] [LB: 18.480649565702137]
# 	['1', '3', '4'] [LB: 20.868955904693667]
# 	['1', '3', '5'] [LB: 21.577467692074123]
# 	['1', '3', '2'] [LB: 17.935201547501446]
# 	['1', '3', '2', '6'] [LB: 18.445455968746685]
# 	['1', '3', '2', '4'] [LB: 20.929167750749016]
# ======= Iteration 8 =======
# Current best tour: ['1', '3', '2', '5', '4', '6'] Length: 23.334841219906476
# Treat problem ['1', '3', '2', '4'] [LB: 20.929167750749016]
# --> Branch
# List of problems to treat:
# 	['1'] [LB: 17.215059123497515]
# 	['1', '2'] [LB: 17.314092579818546]
# 	['1', '5'] [LB: 21.0029496864565]
# 	['1', '6'] [LB: 18.593608197898767]
# 	['1', '4'] [LB: 21.495222661589793]
# 	['1', '3'] [LB: 17.935201547501446]
# 	['1', '3', '6'] [LB: 18.480649565702137]
# 	['1', '3', '4'] [LB: 20.868955904693667]
# 	['1', '3', '5'] [LB: 21.577467692074123]
# 	['1', '3', '2'] [LB: 17.935201547501446]
# 	['1', '3', '2', '6'] [LB: 18.445455968746685]
# 	['1', '3', '2', '4'] [LB: 20.929167750749016]
# 	['1', '3', '2', '4', '6'] [LB: 21.185216776362108]
# 	['1', '3', '2', '4', '5'] [LB: 20.929167750749016]
# ======= Iteration 9 =======
# Current best tour: ['1', '3', '2', '5', '4', '6'] Length: 23.334841219906476
# Treat problem ['1', '3', '2', '4', '5'] [LB: 20.929167750749016]
# --> Optimal solution of ['1', '3', '2', '4', '5'] (Opt: 22.876859387557424): ['1', '3', '2', '4', '5', '6']
# List of problems to treat:
# 	['1'] [LB: 17.215059123497515]
# 	['1', '2'] [LB: 17.314092579818546]
# 	['1', '5'] [LB: 21.0029496864565]
# 	['1', '6'] [LB: 18.593608197898767]
# 	['1', '4'] [LB: 21.495222661589793]
# 	['1', '3'] [LB: 17.935201547501446]
# 	['1', '3', '6'] [LB: 18.480649565702137]
# 	['1', '3', '4'] [LB: 20.868955904693667]
# 	['1', '3', '5'] [LB: 21.577467692074123]
# 	['1', '3', '2'] [LB: 17.935201547501446]
# 	['1', '3', '2', '6'] [LB: 18.445455968746685]
# 	['1', '3', '2', '4'] [LB: 20.929167750749016]
# 	['1', '3', '2', '4', '6'] [LB: 21.185216776362108]
# ======= Iteration 10 =======
# Current best tour: ['1', '3', '2', '4', '5', '6'] Length: 22.876859387557424
# Treat problem ['1', '3', '2', '4', '6'] [LB: 21.185216776362108]
# --> Optimal solution of ['1', '3', '2', '4', '6'] (Opt: 26.160257785659294): ['1', '3', '2', '4', '6', '5']
# List of problems to treat:
# 	['1'] [LB: 17.215059123497515]
# 	['1', '2'] [LB: 17.314092579818546]
# 	['1', '5'] [LB: 21.0029496864565]
# 	['1', '6'] [LB: 18.593608197898767]
# 	['1', '4'] [LB: 21.495222661589793]
# 	['1', '3'] [LB: 17.935201547501446]
# 	['1', '3', '6'] [LB: 18.480649565702137]
# 	['1', '3', '4'] [LB: 20.868955904693667]
# 	['1', '3', '5'] [LB: 21.577467692074123]
# 	['1', '3', '2'] [LB: 17.935201547501446]
# 	['1', '3', '2', '6'] [LB: 18.445455968746685]
# 	['1', '3', '2', '4'] [LB: 20.929167750749016]
# ======= Iteration 11 =======
# Current best tour: ['1', '3', '2', '4', '5', '6'] Length: 22.876859387557424
# Treat problem ['1', '3', '2', '4'] [LB: 20.929167750749016]
# --> Optimal solution of ['1', '3', '2', '4'] (Opt: 22.876859387557424): ['1', '3', '2', '4', '5', '6']
# List of problems to treat:
# 	['1'] [LB: 17.215059123497515]
# 	['1', '2'] [LB: 17.314092579818546]
# 	['1', '5'] [LB: 21.0029496864565]
# 	['1', '6'] [LB: 18.593608197898767]
# 	['1', '4'] [LB: 21.495222661589793]
# 	['1', '3'] [LB: 17.935201547501446]
# 	['1', '3', '6'] [LB: 18.480649565702137]
# 	['1', '3', '4'] [LB: 20.868955904693667]
# 	['1', '3', '5'] [LB: 21.577467692074123]
# 	['1', '3', '2'] [LB: 17.935201547501446]
# 	['1', '3', '2', '6'] [LB: 18.445455968746685]
# ======= Iteration 12 =======
# Current best tour: ['1', '3', '2', '4', '5', '6'] Length: 22.876859387557424
# Treat problem ['1', '3', '2', '6'] [LB: 18.445455968746685]
# --> Branch
# List of problems to treat:
# 	['1'] [LB: 17.215059123497515]
# 	['1', '2'] [LB: 17.314092579818546]
# 	['1', '5'] [LB: 21.0029496864565]
# 	['1', '6'] [LB: 18.593608197898767]
# 	['1', '4'] [LB: 21.495222661589793]
# 	['1', '3'] [LB: 17.935201547501446]
# 	['1', '3', '6'] [LB: 18.480649565702137]
# 	['1', '3', '4'] [LB: 20.868955904693667]
# 	['1', '3', '5'] [LB: 21.577467692074123]
# 	['1', '3', '2'] [LB: 17.935201547501446]
# 	['1', '3', '2', '6'] [LB: 18.445455968746685]
# 	['1', '3', '2', '6', '4'] [LB: 18.652639672835893]
# 	['1', '3', '2', '6', '5'] [LB: 19.01459853115384]
# ======= Iteration 13 =======
# Current best tour: ['1', '3', '2', '4', '5', '6'] Length: 22.876859387557424
# Treat problem ['1', '3', '2', '6', '5'] [LB: 19.01459853115384]
# --> Optimal solution of ['1', '3', '2', '6', '5'] (Opt: 23.29476206924612): ['1', '3', '2', '6', '5', '4']
# List of problems to treat:
# 	['1'] [LB: 17.215059123497515]
# 	['1', '2'] [LB: 17.314092579818546]
# 	['1', '5'] [LB: 21.0029496864565]
# 	['1', '6'] [LB: 18.593608197898767]
# 	['1', '4'] [LB: 21.495222661589793]
# 	['1', '3'] [LB: 17.935201547501446]
# 	['1', '3', '6'] [LB: 18.480649565702137]
# 	['1', '3', '4'] [LB: 20.868955904693667]
# 	['1', '3', '5'] [LB: 21.577467692074123]
# 	['1', '3', '2'] [LB: 17.935201547501446]
# 	['1', '3', '2', '6'] [LB: 18.445455968746685]
# 	['1', '3', '2', '6', '4'] [LB: 18.652639672835893]
# ======= Iteration 14 =======
# Current best tour: ['1', '3', '2', '4', '5', '6'] Length: 22.876859387557424
# Treat problem ['1', '3', '2', '6', '4'] [LB: 18.652639672835893]
# --> Optimal solution of ['1', '3', '2', '6', '4'] (Opt: 22.440530235794878): ['1', '3', '2', '6', '4', '5']
# List of problems to treat:
# 	['1'] [LB: 17.215059123497515]
# 	['1', '2'] [LB: 17.314092579818546]
# 	['1', '5'] [LB: 21.0029496864565]
# 	['1', '6'] [LB: 18.593608197898767]
# 	['1', '4'] [LB: 21.495222661589793]
# 	['1', '3'] [LB: 17.935201547501446]
# 	['1', '3', '6'] [LB: 18.480649565702137]
# 	['1', '3', '4'] [LB: 20.868955904693667]
# 	['1', '3', '5'] [LB: 21.577467692074123]
# 	['1', '3', '2'] [LB: 17.935201547501446]
# 	['1', '3', '2', '6'] [LB: 18.445455968746685]
# ======= Iteration 15 =======
# Current best tour: ['1', '3', '2', '6', '4', '5'] Length: 22.440530235794878
# Treat problem ['1', '3', '2', '6'] [LB: 18.445455968746685]
# --> Optimal solution of ['1', '3', '2', '6'] (Opt: 22.440530235794878): ['1', '3', '2', '6', '4', '5']
# List of problems to treat:
# 	['1'] [LB: 17.215059123497515]
# 	['1', '2'] [LB: 17.314092579818546]
# 	['1', '5'] [LB: 21.0029496864565]
# 	['1', '6'] [LB: 18.593608197898767]
# 	['1', '4'] [LB: 21.495222661589793]
# 	['1', '3'] [LB: 17.935201547501446]
# 	['1', '3', '6'] [LB: 18.480649565702137]
# 	['1', '3', '4'] [LB: 20.868955904693667]
# 	['1', '3', '5'] [LB: 21.577467692074123]
# 	['1', '3', '2'] [LB: 17.935201547501446]
# ======= Iteration 16 =======
# Current best tour: ['1', '3', '2', '6', '4', '5'] Length: 22.440530235794878
# Treat problem ['1', '3', '2'] [LB: 17.935201547501446]
# --> Optimal solution of ['1', '3', '2'] (Opt: 22.440530235794878): ['1', '3', '2', '6', '4', '5']
# List of problems to treat:
# 	['1'] [LB: 17.215059123497515]
# 	['1', '2'] [LB: 17.314092579818546]
# 	['1', '5'] [LB: 21.0029496864565]
# 	['1', '6'] [LB: 18.593608197898767]
# 	['1', '4'] [LB: 21.495222661589793]
# 	['1', '3'] [LB: 17.935201547501446]
# 	['1', '3', '6'] [LB: 18.480649565702137]
# 	['1', '3', '4'] [LB: 20.868955904693667]
# 	['1', '3', '5'] [LB: 21.577467692074123]
# ======= Iteration 17 =======
# Current best tour: ['1', '3', '2', '6', '4', '5'] Length: 22.440530235794878
# Treat problem ['1', '3', '5'] [LB: 21.577467692074123]
# --> Branch
# List of problems to treat:
# 	['1'] [LB: 17.215059123497515]
# 	['1', '2'] [LB: 17.314092579818546]
# 	['1', '5'] [LB: 21.0029496864565]
# 	['1', '6'] [LB: 18.593608197898767]
# 	['1', '4'] [LB: 21.495222661589793]
# 	['1', '3'] [LB: 17.935201547501446]
# 	['1', '3', '6'] [LB: 18.480649565702137]
# 	['1', '3', '4'] [LB: 20.868955904693667]
# 	['1', '3', '5'] [LB: 21.577467692074123]
# 	['1', '3', '5', '6'] [LB: 22.557434434323113]
# 	['1', '3', '5', '4'] [LB: 21.577467692074123]
# 	['1', '3', '5', '2'] [LB: 26.00938246991973]
# Discard ['1', '3', '5', '6'] [LB: 22.557434434323113] because lb=22.557434434323113 >= 22.440530235794878
# Discard ['1', '3', '5', '2'] [LB: 26.00938246991973] because lb=26.00938246991973 >= 22.440530235794878
# ======= Iteration 19 =======
# Current best tour: ['1', '3', '2', '6', '4', '5'] Length: 22.440530235794878
# Treat problem ['1', '3', '5', '4'] [LB: 21.577467692074123]
# --> Branch
# List of problems to treat:
# 	['1'] [LB: 17.215059123497515]
# 	['1', '2'] [LB: 17.314092579818546]
# 	['1', '5'] [LB: 21.0029496864565]
# 	['1', '6'] [LB: 18.593608197898767]
# 	['1', '4'] [LB: 21.495222661589793]
# 	['1', '3'] [LB: 17.935201547501446]
# 	['1', '3', '6'] [LB: 18.480649565702137]
# 	['1', '3', '4'] [LB: 20.868955904693667]
# 	['1', '3', '5'] [LB: 21.577467692074123]
# 	['1', '3', '5', '4'] [LB: 21.577467692074123]
# 	['1', '3', '5', '4', '6'] [LB: 21.577467692074123]
# 	['1', '3', '5', '4', '2'] [LB: 24.57143389532169]
# Discard ['1', '3', '5', '4', '2'] [LB: 24.57143389532169] because lb=24.57143389532169 >= 22.440530235794878
# ======= Iteration 21 =======
# Current best tour: ['1', '3', '2', '6', '4', '5'] Length: 22.440530235794878
# Treat problem ['1', '3', '5', '4', '6'] [LB: 21.577467692074123]
# --> Optimal solution of ['1', '3', '5', '4', '6'] (Opt: 23.656825417264734): ['1', '3', '5', '4', '6', '2']
# List of problems to treat:
# 	['1'] [LB: 17.215059123497515]
# 	['1', '2'] [LB: 17.314092579818546]
# 	['1', '5'] [LB: 21.0029496864565]
# 	['1', '6'] [LB: 18.593608197898767]
# 	['1', '4'] [LB: 21.495222661589793]
# 	['1', '3'] [LB: 17.935201547501446]
# 	['1', '3', '6'] [LB: 18.480649565702137]
# 	['1', '3', '4'] [LB: 20.868955904693667]
# 	['1', '3', '5'] [LB: 21.577467692074123]
# 	['1', '3', '5', '4'] [LB: 21.577467692074123]
# ======= Iteration 22 =======
# Current best tour: ['1', '3', '2', '6', '4', '5'] Length: 22.440530235794878
# Treat problem ['1', '3', '5', '4'] [LB: 21.577467692074123]
# --> Optimal solution of ['1', '3', '5', '4'] (Opt: 23.656825417264734): ['1', '3', '5', '4', '6', '2']
# List of problems to treat:
# 	['1'] [LB: 17.215059123497515]
# 	['1', '2'] [LB: 17.314092579818546]
# 	['1', '5'] [LB: 21.0029496864565]
# 	['1', '6'] [LB: 18.593608197898767]
# 	['1', '4'] [LB: 21.495222661589793]
# 	['1', '3'] [LB: 17.935201547501446]
# 	['1', '3', '6'] [LB: 18.480649565702137]
# 	['1', '3', '4'] [LB: 20.868955904693667]
# 	['1', '3', '5'] [LB: 21.577467692074123]
# ======= Iteration 24 =======
# Current best tour: ['1', '3', '2', '6', '4', '5'] Length: 22.440530235794878
# Treat problem ['1', '3', '5'] [LB: 21.577467692074123]
# --> Optimal solution of ['1', '3', '5'] (Opt: 23.656825417264734): ['1', '3', '5', '4', '6', '2']
# List of problems to treat:
# 	['1'] [LB: 17.215059123497515]
# 	['1', '2'] [LB: 17.314092579818546]
# 	['1', '5'] [LB: 21.0029496864565]
# 	['1', '6'] [LB: 18.593608197898767]
# 	['1', '4'] [LB: 21.495222661589793]
# 	['1', '3'] [LB: 17.935201547501446]
# 	['1', '3', '6'] [LB: 18.480649565702137]
# 	['1', '3', '4'] [LB: 20.868955904693667]
# ======= Iteration 25 =======
# Current best tour: ['1', '3', '2', '6', '4', '5'] Length: 22.440530235794878
# Treat problem ['1', '3', '4'] [LB: 20.868955904693667]
# --> Branch
# List of problems to treat:
# 	['1'] [LB: 17.215059123497515]
# 	['1', '2'] [LB: 17.314092579818546]
# 	['1', '5'] [LB: 21.0029496864565]
# 	['1', '6'] [LB: 18.593608197898767]
# 	['1', '4'] [LB: 21.495222661589793]
# 	['1', '3'] [LB: 17.935201547501446]
# 	['1', '3', '6'] [LB: 18.480649565702137]
# 	['1', '3', '4'] [LB: 20.868955904693667]
# 	['1', '3', '4', '6'] [LB: 21.125004930306762]
# 	['1', '3', '4', '5'] [LB: 20.868955904693667]
# 	['1', '3', '4', '2'] [LB: 24.11897113355433]
# Discard ['1', '3', '4', '2'] [LB: 24.11897113355433] because lb=24.11897113355433 >= 22.440530235794878
# ======= Iteration 27 =======
# Current best tour: ['1', '3', '2', '6', '4', '5'] Length: 22.440530235794878
# Treat problem ['1', '3', '4', '5'] [LB: 20.868955904693667]
# --> Branch
# List of problems to treat:
# 	['1'] [LB: 17.215059123497515]
# 	['1', '2'] [LB: 17.314092579818546]
# 	['1', '5'] [LB: 21.0029496864565]
# 	['1', '6'] [LB: 18.593608197898767]
# 	['1', '4'] [LB: 21.495222661589793]
# 	['1', '3'] [LB: 17.935201547501446]
# 	['1', '3', '6'] [LB: 18.480649565702137]
# 	['1', '3', '4'] [LB: 20.868955904693667]
# 	['1', '3', '4', '6'] [LB: 21.125004930306762]
# 	['1', '3', '4', '5'] [LB: 20.868955904693667]
# 	['1', '3', '4', '5', '6'] [LB: 21.23091476301162]
# 	['1', '3', '4', '5', '2'] [LB: 24.68286279860823]
# Discard ['1', '3', '4', '5', '2'] [LB: 24.68286279860823] because lb=24.68286279860823 >= 22.440530235794878
# ======= Iteration 29 =======
# Current best tour: ['1', '3', '2', '6', '4', '5'] Length: 22.440530235794878
# Treat problem ['1', '3', '4', '5', '6'] [LB: 21.23091476301162]
# --> Optimal solution of ['1', '3', '4', '5', '6'] (Opt: 23.310272488202227): ['1', '3', '4', '5', '6', '2']
# List of problems to treat:
# 	['1'] [LB: 17.215059123497515]
# 	['1', '2'] [LB: 17.314092579818546]
# 	['1', '5'] [LB: 21.0029496864565]
# 	['1', '6'] [LB: 18.593608197898767]
# 	['1', '4'] [LB: 21.495222661589793]
# 	['1', '3'] [LB: 17.935201547501446]
# 	['1', '3', '6'] [LB: 18.480649565702137]
# 	['1', '3', '4'] [LB: 20.868955904693667]
# 	['1', '3', '4', '6'] [LB: 21.125004930306762]
# 	['1', '3', '4', '5'] [LB: 20.868955904693667]
# ======= Iteration 30 =======
# Current best tour: ['1', '3', '2', '6', '4', '5'] Length: 22.440530235794878
# Treat problem ['1', '3', '4', '5'] [LB: 20.868955904693667]
# --> Optimal solution of ['1', '3', '4', '5'] (Opt: 23.310272488202227): ['1', '3', '4', '5', '6', '2']
# List of problems to treat:
# 	['1'] [LB: 17.215059123497515]
# 	['1', '2'] [LB: 17.314092579818546]
# 	['1', '5'] [LB: 21.0029496864565]
# 	['1', '6'] [LB: 18.593608197898767]
# 	['1', '4'] [LB: 21.495222661589793]
# 	['1', '3'] [LB: 17.935201547501446]
# 	['1', '3', '6'] [LB: 18.480649565702137]
# 	['1', '3', '4'] [LB: 20.868955904693667]
# 	['1', '3', '4', '6'] [LB: 21.125004930306762]
# ======= Iteration 31 =======
# Current best tour: ['1', '3', '2', '6', '4', '5'] Length: 22.440530235794878
# Treat problem ['1', '3', '4', '6'] [LB: 21.125004930306762]
# --> Branch
# List of problems to treat:
# 	['1'] [LB: 17.215059123497515]
# 	['1', '2'] [LB: 17.314092579818546]
# 	['1', '5'] [LB: 21.0029496864565]
# 	['1', '6'] [LB: 18.593608197898767]
# 	['1', '4'] [LB: 21.495222661589793]
# 	['1', '3'] [LB: 17.935201547501446]
# 	['1', '3', '6'] [LB: 18.480649565702137]
# 	['1', '3', '4'] [LB: 20.868955904693667]
# 	['1', '3', '4', '6'] [LB: 21.125004930306762]
# 	['1', '3', '4', '6', '5'] [LB: 21.694147492713917]
# 	['1', '3', '4', '6', '2'] [LB: 21.842443055641205]
# ======= Iteration 32 =======
# Current best tour: ['1', '3', '2', '6', '4', '5'] Length: 22.440530235794878
# Treat problem ['1', '3', '4', '6', '2'] [LB: 21.842443055641205]
# --> Optimal solution of ['1', '3', '4', '6', '2'] (Opt: 31.32513453998093): ['1', '3', '4', '6', '2', '5']
# List of problems to treat:
# 	['1'] [LB: 17.215059123497515]
# 	['1', '2'] [LB: 17.314092579818546]
# 	['1', '5'] [LB: 21.0029496864565]
# 	['1', '6'] [LB: 18.593608197898767]
# 	['1', '4'] [LB: 21.495222661589793]
# 	['1', '3'] [LB: 17.935201547501446]
# 	['1', '3', '6'] [LB: 18.480649565702137]
# 	['1', '3', '4'] [LB: 20.868955904693667]
# 	['1', '3', '4', '6'] [LB: 21.125004930306762]
# 	['1', '3', '4', '6', '5'] [LB: 21.694147492713917]
# ======= Iteration 33 =======
# Current best tour: ['1', '3', '2', '6', '4', '5'] Length: 22.440530235794878
# Treat problem ['1', '3', '4', '6', '5'] [LB: 21.694147492713917]
# --> Optimal solution of ['1', '3', '4', '6', '5'] (Opt: 27.487981870415688): ['1', '3', '4', '6', '5', '2']
# List of problems to treat:
# 	['1'] [LB: 17.215059123497515]
# 	['1', '2'] [LB: 17.314092579818546]
# 	['1', '5'] [LB: 21.0029496864565]
# 	['1', '6'] [LB: 18.593608197898767]
# 	['1', '4'] [LB: 21.495222661589793]
# 	['1', '3'] [LB: 17.935201547501446]
# 	['1', '3', '6'] [LB: 18.480649565702137]
# 	['1', '3', '4'] [LB: 20.868955904693667]
# 	['1', '3', '4', '6'] [LB: 21.125004930306762]
# ======= Iteration 34 =======
# Current best tour: ['1', '3', '2', '6', '4', '5'] Length: 22.440530235794878
# Treat problem ['1', '3', '4', '6'] [LB: 21.125004930306762]
# --> Optimal solution of ['1', '3', '4', '6'] (Opt: 27.487981870415688): ['1', '3', '4', '6', '5', '2']
# List of problems to treat:
# 	['1'] [LB: 17.215059123497515]
# 	['1', '2'] [LB: 17.314092579818546]
# 	['1', '5'] [LB: 21.0029496864565]
# 	['1', '6'] [LB: 18.593608197898767]
# 	['1', '4'] [LB: 21.495222661589793]
# 	['1', '3'] [LB: 17.935201547501446]
# 	['1', '3', '6'] [LB: 18.480649565702137]
# 	['1', '3', '4'] [LB: 20.868955904693667]
# ======= Iteration 35 =======
# Current best tour: ['1', '3', '2', '6', '4', '5'] Length: 22.440530235794878
# Treat problem ['1', '3', '4'] [LB: 20.868955904693667]
# --> Optimal solution of ['1', '3', '4'] (Opt: 23.310272488202227): ['1', '3', '4', '5', '6', '2']
# List of problems to treat:
# 	['1'] [LB: 17.215059123497515]
# 	['1', '2'] [LB: 17.314092579818546]
# 	['1', '5'] [LB: 21.0029496864565]
# 	['1', '6'] [LB: 18.593608197898767]
# 	['1', '4'] [LB: 21.495222661589793]
# 	['1', '3'] [LB: 17.935201547501446]
# 	['1', '3', '6'] [LB: 18.480649565702137]
# ======= Iteration 36 =======
# Current best tour: ['1', '3', '2', '6', '4', '5'] Length: 22.440530235794878
# Treat problem ['1', '3', '6'] [LB: 18.480649565702137]
# --> Branch
# List of problems to treat:
# 	['1'] [LB: 17.215059123497515]
# 	['1', '2'] [LB: 17.314092579818546]
# 	['1', '5'] [LB: 21.0029496864565]
# 	['1', '6'] [LB: 18.593608197898767]
# 	['1', '4'] [LB: 21.495222661589793]
# 	['1', '3'] [LB: 17.935201547501446]
# 	['1', '3', '6'] [LB: 18.480649565702137]
# 	['1', '3', '6', '4'] [LB: 18.480649565702137]
# 	['1', '3', '6', '5'] [LB: 18.84260842402009]
# 	['1', '3', '6', '2'] [LB: 18.990903986947377]
# ======= Iteration 37 =======
# Current best tour: ['1', '3', '2', '6', '4', '5'] Length: 22.440530235794878
# Treat problem ['1', '3', '6', '2'] [LB: 18.990903986947377]
# --> Branch
# List of problems to treat:
# 	['1'] [LB: 17.215059123497515]
# 	['1', '2'] [LB: 17.314092579818546]
# 	['1', '5'] [LB: 21.0029496864565]
# 	['1', '6'] [LB: 18.593608197898767]
# 	['1', '4'] [LB: 21.495222661589793]
# 	['1', '3'] [LB: 17.935201547501446]
# 	['1', '3', '6'] [LB: 18.480649565702137]
# 	['1', '3', '6', '4'] [LB: 18.480649565702137]
# 	['1', '3', '6', '5'] [LB: 18.84260842402009]
# 	['1', '3', '6', '2'] [LB: 18.990903986947377]
# 	['1', '3', '6', '2', '4'] [LB: 23.24775633373008]
# 	['1', '3', '6', '2', '5'] [LB: 24.067697024397074]
# Discard ['1', '3', '6', '2', '4'] [LB: 23.24775633373008] because lb=23.24775633373008 >= 22.440530235794878
# Discard ['1', '3', '6', '2', '5'] [LB: 24.067697024397074] because lb=24.067697024397074 >= 22.440530235794878
# ======= Iteration 40 =======
# Current best tour: ['1', '3', '2', '6', '4', '5'] Length: 22.440530235794878
# Treat problem ['1', '3', '6', '2'] [LB: 18.990903986947377]
# --> Optimal solution of ['1', '3', '6', '2'] (Opt: inf): None
# List of problems to treat:
# 	['1'] [LB: 17.215059123497515]
# 	['1', '2'] [LB: 17.314092579818546]
# 	['1', '5'] [LB: 21.0029496864565]
# 	['1', '6'] [LB: 18.593608197898767]
# 	['1', '4'] [LB: 21.495222661589793]
# 	['1', '3'] [LB: 17.935201547501446]
# 	['1', '3', '6'] [LB: 18.480649565702137]
# 	['1', '3', '6', '4'] [LB: 18.480649565702137]
# 	['1', '3', '6', '5'] [LB: 18.84260842402009]
# ======= Iteration 41 =======
# Current best tour: ['1', '3', '2', '6', '4', '5'] Length: 22.440530235794878
# Treat problem ['1', '3', '6', '5'] [LB: 18.84260842402009]
# --> Branch
# List of problems to treat:
# 	['1'] [LB: 17.215059123497515]
# 	['1', '2'] [LB: 17.314092579818546]
# 	['1', '5'] [LB: 21.0029496864565]
# 	['1', '6'] [LB: 18.593608197898767]
# 	['1', '4'] [LB: 21.495222661589793]
# 	['1', '3'] [LB: 17.935201547501446]
# 	['1', '3', '6'] [LB: 18.480649565702137]
# 	['1', '3', '6', '4'] [LB: 18.480649565702137]
# 	['1', '3', '6', '5'] [LB: 18.84260842402009]
# 	['1', '3', '6', '5', '4'] [LB: 18.84260842402009]
# 	['1', '3', '6', '5', '2'] [LB: 23.274523201865694]
# Discard ['1', '3', '6', '5', '2'] [LB: 23.274523201865694] because lb=23.274523201865694 >= 22.440530235794878
# ======= Iteration 43 =======
# Current best tour: ['1', '3', '2', '6', '4', '5'] Length: 22.440530235794878
# Treat problem ['1', '3', '6', '5', '4'] [LB: 18.84260842402009]
# --> Optimal solution of ['1', '3', '6', '5', '4'] (Opt: 23.198494227123824): ['1', '3', '6', '5', '4', '2']
# List of problems to treat:
# 	['1'] [LB: 17.215059123497515]
# 	['1', '2'] [LB: 17.314092579818546]
# 	['1', '5'] [LB: 21.0029496864565]
# 	['1', '6'] [LB: 18.593608197898767]
# 	['1', '4'] [LB: 21.495222661589793]
# 	['1', '3'] [LB: 17.935201547501446]
# 	['1', '3', '6'] [LB: 18.480649565702137]
# 	['1', '3', '6', '4'] [LB: 18.480649565702137]
# 	['1', '3', '6', '5'] [LB: 18.84260842402009]
# ======= Iteration 44 =======
# Current best tour: ['1', '3', '2', '6', '4', '5'] Length: 22.440530235794878
# Treat problem ['1', '3', '6', '5'] [LB: 18.84260842402009]
# --> Optimal solution of ['1', '3', '6', '5'] (Opt: 23.198494227123824): ['1', '3', '6', '5', '4', '2']
# List of problems to treat:
# 	['1'] [LB: 17.215059123497515]
# 	['1', '2'] [LB: 17.314092579818546]
# 	['1', '5'] [LB: 21.0029496864565]
# 	['1', '6'] [LB: 18.593608197898767]
# 	['1', '4'] [LB: 21.495222661589793]
# 	['1', '3'] [LB: 17.935201547501446]
# 	['1', '3', '6'] [LB: 18.480649565702137]
# 	['1', '3', '6', '4'] [LB: 18.480649565702137]
# ======= Iteration 45 =======
# Current best tour: ['1', '3', '2', '6', '4', '5'] Length: 22.440530235794878
# Treat problem ['1', '3', '6', '4'] [LB: 18.480649565702137]
# --> Branch
# List of problems to treat:
# 	['1'] [LB: 17.215059123497515]
# 	['1', '2'] [LB: 17.314092579818546]
# 	['1', '5'] [LB: 21.0029496864565]
# 	['1', '6'] [LB: 18.593608197898767]
# 	['1', '4'] [LB: 21.495222661589793]
# 	['1', '3'] [LB: 17.935201547501446]
# 	['1', '3', '6'] [LB: 18.480649565702137]
# 	['1', '3', '6', '4'] [LB: 18.480649565702137]
# 	['1', '3', '6', '4', '5'] [LB: 18.480649565702137]
# 	['1', '3', '6', '4', '2'] [LB: 21.7306647945628]
# ======= Iteration 46 =======
# Current best tour: ['1', '3', '2', '6', '4', '5'] Length: 22.440530235794878
# Treat problem ['1', '3', '6', '4', '2'] [LB: 21.7306647945628]
# --> Optimal solution of ['1', '3', '6', '4', '2'] (Opt: 31.213356278902527): ['1', '3', '6', '4', '2', '5']
# List of problems to treat:
# 	['1'] [LB: 17.215059123497515]
# 	['1', '2'] [LB: 17.314092579818546]
# 	['1', '5'] [LB: 21.0029496864565]
# 	['1', '6'] [LB: 18.593608197898767]
# 	['1', '4'] [LB: 21.495222661589793]
# 	['1', '3'] [LB: 17.935201547501446]
# 	['1', '3', '6'] [LB: 18.480649565702137]
# 	['1', '3', '6', '4'] [LB: 18.480649565702137]
# 	['1', '3', '6', '4', '5'] [LB: 18.480649565702137]
# ======= Iteration 47 =======
# Current best tour: ['1', '3', '2', '6', '4', '5'] Length: 22.440530235794878
# Treat problem ['1', '3', '6', '4', '5'] [LB: 18.480649565702137]
# --> Optimal solution of ['1', '3', '6', '4', '5'] (Opt: 23.65647605947287): ['1', '3', '6', '4', '5', '2']
# List of problems to treat:
# 	['1'] [LB: 17.215059123497515]
# 	['1', '2'] [LB: 17.314092579818546]
# 	['1', '5'] [LB: 21.0029496864565]
# 	['1', '6'] [LB: 18.593608197898767]
# 	['1', '4'] [LB: 21.495222661589793]
# 	['1', '3'] [LB: 17.935201547501446]
# 	['1', '3', '6'] [LB: 18.480649565702137]
# 	['1', '3', '6', '4'] [LB: 18.480649565702137]
# ======= Iteration 48 =======
# Current best tour: ['1', '3', '2', '6', '4', '5'] Length: 22.440530235794878
# Treat problem ['1', '3', '6', '4'] [LB: 18.480649565702137]
# --> Optimal solution of ['1', '3', '6', '4'] (Opt: 23.65647605947287): ['1', '3', '6', '4', '5', '2']
# List of problems to treat:
# 	['1'] [LB: 17.215059123497515]
# 	['1', '2'] [LB: 17.314092579818546]
# 	['1', '5'] [LB: 21.0029496864565]
# 	['1', '6'] [LB: 18.593608197898767]
# 	['1', '4'] [LB: 21.495222661589793]
# 	['1', '3'] [LB: 17.935201547501446]
# 	['1', '3', '6'] [LB: 18.480649565702137]
# ======= Iteration 49 =======
# Current best tour: ['1', '3', '2', '6', '4', '5'] Length: 22.440530235794878
# Treat problem ['1', '3', '6'] [LB: 18.480649565702137]
# --> Optimal solution of ['1', '3', '6'] (Opt: 23.198494227123824): ['1', '3', '6', '5', '4', '2']
# List of problems to treat:
# 	['1'] [LB: 17.215059123497515]
# 	['1', '2'] [LB: 17.314092579818546]
# 	['1', '5'] [LB: 21.0029496864565]
# 	['1', '6'] [LB: 18.593608197898767]
# 	['1', '4'] [LB: 21.495222661589793]
# 	['1', '3'] [LB: 17.935201547501446]
# ======= Iteration 50 =======
# Current best tour: ['1', '3', '2', '6', '4', '5'] Length: 22.440530235794878
# Treat problem ['1', '3'] [LB: 17.935201547501446]
# --> Optimal solution of ['1', '3'] (Opt: 22.440530235794878): ['1', '3', '2', '6', '4', '5']
# List of problems to treat:
# 	['1'] [LB: 17.215059123497515]
# 	['1', '2'] [LB: 17.314092579818546]
# 	['1', '5'] [LB: 21.0029496864565]
# 	['1', '6'] [LB: 18.593608197898767]
# 	['1', '4'] [LB: 21.495222661589793]
# ======= Iteration 51 =======
# Current best tour: ['1', '3', '2', '6', '4', '5'] Length: 22.440530235794878
# Treat problem ['1', '4'] [LB: 21.495222661589793]
# --> Branch
# List of problems to treat:
# 	['1'] [LB: 17.215059123497515]
# 	['1', '2'] [LB: 17.314092579818546]
# 	['1', '5'] [LB: 21.0029496864565]
# 	['1', '6'] [LB: 18.593608197898767]
# 	['1', '4'] [LB: 21.495222661589793]
# 	['1', '4', '6'] [LB: 21.751271687202888]
# 	['1', '4', '3'] [LB: 24.139578026194414]
# 	['1', '4', '5'] [LB: 21.495222661589793]
# 	['1', '4', '2'] [LB: 24.745237890450454]
# Discard ['1', '4', '3'] [LB: 24.139578026194414] because lb=24.139578026194414 >= 22.440530235794878
# Discard ['1', '4', '2'] [LB: 24.745237890450454] because lb=24.745237890450454 >= 22.440530235794878
# ======= Iteration 53 =======
# Current best tour: ['1', '3', '2', '6', '4', '5'] Length: 22.440530235794878
# Treat problem ['1', '4', '5'] [LB: 21.495222661589793]
# --> Branch
# List of problems to treat:
# 	['1'] [LB: 17.215059123497515]
# 	['1', '2'] [LB: 17.314092579818546]
# 	['1', '5'] [LB: 21.0029496864565]
# 	['1', '6'] [LB: 18.593608197898767]
# 	['1', '4'] [LB: 21.495222661589793]
# 	['1', '4', '6'] [LB: 21.751271687202888]
# 	['1', '4', '5'] [LB: 21.495222661589793]
# 	['1', '4', '5', '6'] [LB: 21.857181519907744]
# 	['1', '4', '5', '3'] [LB: 24.592040787961775]
# 	['1', '4', '5', '2'] [LB: 25.30912955550436]
# Discard ['1', '4', '5', '3'] [LB: 24.592040787961775] because lb=24.592040787961775 >= 22.440530235794878
# Discard ['1', '4', '5', '2'] [LB: 25.30912955550436] because lb=25.30912955550436 >= 22.440530235794878
# ======= Iteration 56 =======
# Current best tour: ['1', '3', '2', '6', '4', '5'] Length: 22.440530235794878
# Treat problem ['1', '4', '5', '6'] [LB: 21.857181519907744]
# --> Branch
# List of problems to treat:
# 	['1'] [LB: 17.215059123497515]
# 	['1', '2'] [LB: 17.314092579818546]
# 	['1', '5'] [LB: 21.0029496864565]
# 	['1', '6'] [LB: 18.593608197898767]
# 	['1', '4'] [LB: 21.495222661589793]
# 	['1', '4', '6'] [LB: 21.751271687202888]
# 	['1', '4', '5'] [LB: 21.495222661589793]
# 	['1', '4', '5', '6'] [LB: 21.857181519907744]
# 	['1', '4', '5', '6', '3'] [LB: 21.857181519907744]
# 	['1', '4', '5', '6', '2'] [LB: 22.574619645242187]
# Discard ['1', '4', '5', '6', '2'] [LB: 22.574619645242187] because lb=22.574619645242187 >= 22.440530235794878
# ======= Iteration 58 =======
# Current best tour: ['1', '3', '2', '6', '4', '5'] Length: 22.440530235794878
# Treat problem ['1', '4', '5', '6', '3'] [LB: 21.857181519907744]
# --> Optimal solution of ['1', '4', '5', '6', '3'] (Opt: 22.052544133880318): ['1', '4', '5', '6', '3', '2']
# List of problems to treat:
# 	['1'] [LB: 17.215059123497515]
# 	['1', '2'] [LB: 17.314092579818546]
# 	['1', '5'] [LB: 21.0029496864565]
# 	['1', '6'] [LB: 18.593608197898767]
# 	['1', '4'] [LB: 21.495222661589793]
# 	['1', '4', '6'] [LB: 21.751271687202888]
# 	['1', '4', '5'] [LB: 21.495222661589793]
# 	['1', '4', '5', '6'] [LB: 21.857181519907744]
# ======= Iteration 59 =======
# Current best tour: ['1', '4', '5', '6', '3', '2'] Length: 22.052544133880318
# Treat problem ['1', '4', '5', '6'] [LB: 21.857181519907744]
# --> Optimal solution of ['1', '4', '5', '6'] (Opt: 22.052544133880318): ['1', '4', '5', '6', '3', '2']
# List of problems to treat:
# 	['1'] [LB: 17.215059123497515]
# 	['1', '2'] [LB: 17.314092579818546]
# 	['1', '5'] [LB: 21.0029496864565]
# 	['1', '6'] [LB: 18.593608197898767]
# 	['1', '4'] [LB: 21.495222661589793]
# 	['1', '4', '6'] [LB: 21.751271687202888]
# 	['1', '4', '5'] [LB: 21.495222661589793]
# ======= Iteration 60 =======
# Current best tour: ['1', '4', '5', '6', '3', '2'] Length: 22.052544133880318
# Treat problem ['1', '4', '5'] [LB: 21.495222661589793]
# --> Optimal solution of ['1', '4', '5'] (Opt: 22.052544133880318): ['1', '4', '5', '6', '3', '2']
# List of problems to treat:
# 	['1'] [LB: 17.215059123497515]
# 	['1', '2'] [LB: 17.314092579818546]
# 	['1', '5'] [LB: 21.0029496864565]
# 	['1', '6'] [LB: 18.593608197898767]
# 	['1', '4'] [LB: 21.495222661589793]
# 	['1', '4', '6'] [LB: 21.751271687202888]
# ======= Iteration 62 =======
# Current best tour: ['1', '4', '5', '6', '3', '2'] Length: 22.052544133880318
# Treat problem ['1', '4', '6'] [LB: 21.751271687202888]
# --> Branch
# List of problems to treat:
# 	['1'] [LB: 17.215059123497515]
# 	['1', '2'] [LB: 17.314092579818546]
# 	['1', '5'] [LB: 21.0029496864565]
# 	['1', '6'] [LB: 18.593608197898767]
# 	['1', '4'] [LB: 21.495222661589793]
# 	['1', '4', '6'] [LB: 21.751271687202888]
# 	['1', '4', '6', '3'] [LB: 21.751271687202888]
# 	['1', '4', '6', '5'] [LB: 22.32041424961004]
# 	['1', '4', '6', '2'] [LB: 22.46870981253733]
# Discard ['1', '4', '6', '5'] [LB: 22.32041424961004] because lb=22.32041424961004 >= 22.052544133880318
# Discard ['1', '4', '6', '2'] [LB: 22.46870981253733] because lb=22.46870981253733 >= 22.052544133880318
# ======= Iteration 65 =======
# Current best tour: ['1', '4', '5', '6', '3', '2'] Length: 22.052544133880318
# Treat problem ['1', '4', '6', '3'] [LB: 21.751271687202888]
# --> Branch
# List of problems to treat:
# 	['1'] [LB: 17.215059123497515]
# 	['1', '2'] [LB: 17.314092579818546]
# 	['1', '5'] [LB: 21.0029496864565]
# 	['1', '6'] [LB: 18.593608197898767]
# 	['1', '4'] [LB: 21.495222661589793]
# 	['1', '4', '6'] [LB: 21.751271687202888]
# 	['1', '4', '6', '3'] [LB: 21.751271687202888]
# 	['1', '4', '6', '3', '5'] [LB: 25.393537831775557]
# 	['1', '4', '6', '3', '2'] [LB: 21.751271687202888]
# Discard ['1', '4', '6', '3', '5'] [LB: 25.393537831775557] because lb=25.393537831775557 >= 22.052544133880318
# ======= Iteration 66 =======
# Current best tour: ['1', '4', '5', '6', '3', '2'] Length: 22.052544133880318
# Treat problem ['1', '4', '6', '3', '2'] [LB: 21.751271687202888]
# --> Optimal solution of ['1', '4', '6', '3', '2'] (Opt: 30.067406185659017): ['1', '4', '6', '3', '2', '5']
# List of problems to treat:
# 	['1'] [LB: 17.215059123497515]
# 	['1', '2'] [LB: 17.314092579818546]
# 	['1', '5'] [LB: 21.0029496864565]
# 	['1', '6'] [LB: 18.593608197898767]
# 	['1', '4'] [LB: 21.495222661589793]
# 	['1', '4', '6'] [LB: 21.751271687202888]
# 	['1', '4', '6', '3'] [LB: 21.751271687202888]
# ======= Iteration 68 =======
# Current best tour: ['1', '4', '5', '6', '3', '2'] Length: 22.052544133880318
# Treat problem ['1', '4', '6', '3'] [LB: 21.751271687202888]
# --> Optimal solution of ['1', '4', '6', '3'] (Opt: 30.067406185659017): ['1', '4', '6', '3', '2', '5']
# List of problems to treat:
# 	['1'] [LB: 17.215059123497515]
# 	['1', '2'] [LB: 17.314092579818546]
# 	['1', '5'] [LB: 21.0029496864565]
# 	['1', '6'] [LB: 18.593608197898767]
# 	['1', '4'] [LB: 21.495222661589793]
# 	['1', '4', '6'] [LB: 21.751271687202888]
# ======= Iteration 69 =======
# Current best tour: ['1', '4', '5', '6', '3', '2'] Length: 22.052544133880318
# Treat problem ['1', '4', '6'] [LB: 21.751271687202888]
# --> Optimal solution of ['1', '4', '6'] (Opt: 30.067406185659017): ['1', '4', '6', '3', '2', '5']
# List of problems to treat:
# 	['1'] [LB: 17.215059123497515]
# 	['1', '2'] [LB: 17.314092579818546]
# 	['1', '5'] [LB: 21.0029496864565]
# 	['1', '6'] [LB: 18.593608197898767]
# 	['1', '4'] [LB: 21.495222661589793]
# ======= Iteration 70 =======
# Current best tour: ['1', '4', '5', '6', '3', '2'] Length: 22.052544133880318
# Treat problem ['1', '4'] [LB: 21.495222661589793]
# --> Optimal solution of ['1', '4'] (Opt: 22.052544133880318): ['1', '4', '5', '6', '3', '2']
# List of problems to treat:
# 	['1'] [LB: 17.215059123497515]
# 	['1', '2'] [LB: 17.314092579818546]
# 	['1', '5'] [LB: 21.0029496864565]
# 	['1', '6'] [LB: 18.593608197898767]
# ======= Iteration 71 =======
# Current best tour: ['1', '4', '5', '6', '3', '2'] Length: 22.052544133880318
# Treat problem ['1', '6'] [LB: 18.593608197898767]
# --> Branch
# List of problems to treat:
# 	['1'] [LB: 17.215059123497515]
# 	['1', '2'] [LB: 17.314092579818546]
# 	['1', '5'] [LB: 21.0029496864565]
# 	['1', '6'] [LB: 18.593608197898767]
# 	['1', '6', '3'] [LB: 18.593608197898767]
# 	['1', '6', '4'] [LB: 18.800791901987974]
# 	['1', '6', '5'] [LB: 19.162750760305922]
# 	['1', '6', '2'] [LB: 19.311046323233214]
# ======= Iteration 72 =======
# Current best tour: ['1', '4', '5', '6', '3', '2'] Length: 22.052544133880318
# Treat problem ['1', '6', '2'] [LB: 19.311046323233214]
# --> Branch
# List of problems to treat:
# 	['1'] [LB: 17.215059123497515]
# 	['1', '2'] [LB: 17.314092579818546]
# 	['1', '5'] [LB: 21.0029496864565]
# 	['1', '6'] [LB: 18.593608197898767]
# 	['1', '6', '3'] [LB: 18.593608197898767]
# 	['1', '6', '4'] [LB: 18.800791901987974]
# 	['1', '6', '5'] [LB: 19.162750760305922]
# 	['1', '6', '2'] [LB: 19.311046323233214]
# 	['1', '6', '2', '3'] [LB: 19.311046323233214]
# 	['1', '6', '2', '4'] [LB: 23.567898670015918]
# 	['1', '6', '2', '5'] [LB: 24.38783936068291]
# Discard ['1', '6', '2', '4'] [LB: 23.567898670015918] because lb=23.567898670015918 >= 22.052544133880318
# Discard ['1', '6', '2', '5'] [LB: 24.38783936068291] because lb=24.38783936068291 >= 22.052544133880318
# ======= Iteration 75 =======
# Current best tour: ['1', '4', '5', '6', '3', '2'] Length: 22.052544133880318
# Treat problem ['1', '6', '2', '3'] [LB: 19.311046323233214]
# --> Branch
# List of problems to treat:
# 	['1'] [LB: 17.215059123497515]
# 	['1', '2'] [LB: 17.314092579818546]
# 	['1', '5'] [LB: 21.0029496864565]
# 	['1', '6'] [LB: 18.593608197898767]
# 	['1', '6', '3'] [LB: 18.593608197898767]
# 	['1', '6', '4'] [LB: 18.800791901987974]
# 	['1', '6', '5'] [LB: 19.162750760305922]
# 	['1', '6', '2'] [LB: 19.311046323233214]
# 	['1', '6', '2', '3'] [LB: 19.311046323233214]
# 	['1', '6', '2', '3', '4'] [LB: 21.69935266222474]
# 	['1', '6', '2', '3', '5'] [LB: 22.4078644496052]
# Discard ['1', '6', '2', '3', '5'] [LB: 22.4078644496052] because lb=22.4078644496052 >= 22.052544133880318
# ======= Iteration 77 =======
# Current best tour: ['1', '4', '5', '6', '3', '2'] Length: 22.052544133880318
# Treat problem ['1', '6', '2', '3', '4'] [LB: 21.69935266222474]
# --> Optimal solution of ['1', '6', '2', '3', '4'] (Opt: 25.583572382835268): ['1', '6', '2', '3', '4', '5']
# List of problems to treat:
# 	['1'] [LB: 17.215059123497515]
# 	['1', '2'] [LB: 17.314092579818546]
# 	['1', '5'] [LB: 21.0029496864565]
# 	['1', '6'] [LB: 18.593608197898767]
# 	['1', '6', '3'] [LB: 18.593608197898767]
# 	['1', '6', '4'] [LB: 18.800791901987974]
# 	['1', '6', '5'] [LB: 19.162750760305922]
# 	['1', '6', '2'] [LB: 19.311046323233214]
# 	['1', '6', '2', '3'] [LB: 19.311046323233214]
# ======= Iteration 78 =======
# Current best tour: ['1', '4', '5', '6', '3', '2'] Length: 22.052544133880318
# Treat problem ['1', '6', '2', '3'] [LB: 19.311046323233214]
# --> Optimal solution of ['1', '6', '2', '3'] (Opt: 25.583572382835268): ['1', '6', '2', '3', '4', '5']
# List of problems to treat:
# 	['1'] [LB: 17.215059123497515]
# 	['1', '2'] [LB: 17.314092579818546]
# 	['1', '5'] [LB: 21.0029496864565]
# 	['1', '6'] [LB: 18.593608197898767]
# 	['1', '6', '3'] [LB: 18.593608197898767]
# 	['1', '6', '4'] [LB: 18.800791901987974]
# 	['1', '6', '5'] [LB: 19.162750760305922]
# 	['1', '6', '2'] [LB: 19.311046323233214]
# ======= Iteration 79 =======
# Current best tour: ['1', '4', '5', '6', '3', '2'] Length: 22.052544133880318
# Treat problem ['1', '6', '2'] [LB: 19.311046323233214]
# --> Optimal solution of ['1', '6', '2'] (Opt: 25.583572382835268): ['1', '6', '2', '3', '4', '5']
# List of problems to treat:
# 	['1'] [LB: 17.215059123497515]
# 	['1', '2'] [LB: 17.314092579818546]
# 	['1', '5'] [LB: 21.0029496864565]
# 	['1', '6'] [LB: 18.593608197898767]
# 	['1', '6', '3'] [LB: 18.593608197898767]
# 	['1', '6', '4'] [LB: 18.800791901987974]
# 	['1', '6', '5'] [LB: 19.162750760305922]
# ======= Iteration 80 =======
# Current best tour: ['1', '4', '5', '6', '3', '2'] Length: 22.052544133880318
# Treat problem ['1', '6', '5'] [LB: 19.162750760305922]
# --> Branch
# List of problems to treat:
# 	['1'] [LB: 17.215059123497515]
# 	['1', '2'] [LB: 17.314092579818546]
# 	['1', '5'] [LB: 21.0029496864565]
# 	['1', '6'] [LB: 18.593608197898767]
# 	['1', '6', '3'] [LB: 18.593608197898767]
# 	['1', '6', '4'] [LB: 18.800791901987974]
# 	['1', '6', '5'] [LB: 19.162750760305922]
# 	['1', '6', '5', '3'] [LB: 22.877576770608947]
# 	['1', '6', '5', '4'] [LB: 19.162750760305922]
# 	['1', '6', '5', '2'] [LB: 23.59466553815153]
# Discard ['1', '6', '5', '3'] [LB: 22.877576770608947] because lb=22.877576770608947 >= 22.052544133880318
# Discard ['1', '6', '5', '2'] [LB: 23.59466553815153] because lb=23.59466553815153 >= 22.052544133880318
# ======= Iteration 82 =======
# Current best tour: ['1', '4', '5', '6', '3', '2'] Length: 22.052544133880318
# Treat problem ['1', '6', '5', '4'] [LB: 19.162750760305922]
# --> Branch
# List of problems to treat:
# 	['1'] [LB: 17.215059123497515]
# 	['1', '2'] [LB: 17.314092579818546]
# 	['1', '5'] [LB: 21.0029496864565]
# 	['1', '6'] [LB: 18.593608197898767]
# 	['1', '6', '3'] [LB: 18.593608197898767]
# 	['1', '6', '4'] [LB: 18.800791901987974]
# 	['1', '6', '5'] [LB: 19.162750760305922]
# 	['1', '6', '5', '4'] [LB: 19.162750760305922]
# 	['1', '6', '5', '4', '3'] [LB: 21.55105709929745]
# 	['1', '6', '5', '4', '2'] [LB: 22.156716963553492]
# Discard ['1', '6', '5', '4', '2'] [LB: 22.156716963553492] because lb=22.156716963553492 >= 22.052544133880318
# ======= Iteration 84 =======
# Current best tour: ['1', '4', '5', '6', '3', '2'] Length: 22.052544133880318
# Treat problem ['1', '6', '5', '4', '3'] [LB: 21.55105709929745]
# --> Optimal solution of ['1', '6', '5', '4', '3'] (Opt: 21.746419713270026): ['1', '6', '5', '4', '3', '2']
# List of problems to treat:
# 	['1'] [LB: 17.215059123497515]
# 	['1', '2'] [LB: 17.314092579818546]
# 	['1', '5'] [LB: 21.0029496864565]
# 	['1', '6'] [LB: 18.593608197898767]
# 	['1', '6', '3'] [LB: 18.593608197898767]
# 	['1', '6', '4'] [LB: 18.800791901987974]
# 	['1', '6', '5'] [LB: 19.162750760305922]
# 	['1', '6', '5', '4'] [LB: 19.162750760305922]
# ======= Iteration 85 =======
# Current best tour: ['1', '6', '5', '4', '3', '2'] Length: 21.746419713270026
# Treat problem ['1', '6', '5', '4'] [LB: 19.162750760305922]
# --> Optimal solution of ['1', '6', '5', '4'] (Opt: 21.746419713270026): ['1', '6', '5', '4', '3', '2']
# List of problems to treat:
# 	['1'] [LB: 17.215059123497515]
# 	['1', '2'] [LB: 17.314092579818546]
# 	['1', '5'] [LB: 21.0029496864565]
# 	['1', '6'] [LB: 18.593608197898767]
# 	['1', '6', '3'] [LB: 18.593608197898767]
# 	['1', '6', '4'] [LB: 18.800791901987974]
# 	['1', '6', '5'] [LB: 19.162750760305922]
# ======= Iteration 87 =======
# Current best tour: ['1', '6', '5', '4', '3', '2'] Length: 21.746419713270026
# Treat problem ['1', '6', '5'] [LB: 19.162750760305922]
# --> Optimal solution of ['1', '6', '5'] (Opt: 21.746419713270026): ['1', '6', '5', '4', '3', '2']
# List of problems to treat:
# 	['1'] [LB: 17.215059123497515]
# 	['1', '2'] [LB: 17.314092579818546]
# 	['1', '5'] [LB: 21.0029496864565]
# 	['1', '6'] [LB: 18.593608197898767]
# 	['1', '6', '3'] [LB: 18.593608197898767]
# 	['1', '6', '4'] [LB: 18.800791901987974]
# ======= Iteration 88 =======
# Current best tour: ['1', '6', '5', '4', '3', '2'] Length: 21.746419713270026
# Treat problem ['1', '6', '4'] [LB: 18.800791901987974]
# --> Branch
# List of problems to treat:
# 	['1'] [LB: 17.215059123497515]
# 	['1', '2'] [LB: 17.314092579818546]
# 	['1', '5'] [LB: 21.0029496864565]
# 	['1', '6'] [LB: 18.593608197898767]
# 	['1', '6', '3'] [LB: 18.593608197898767]
# 	['1', '6', '4'] [LB: 18.800791901987974]
# 	['1', '6', '4', '3'] [LB: 21.445147266592596]
# 	['1', '6', '4', '5'] [LB: 18.800791901987974]
# 	['1', '6', '4', '2'] [LB: 22.050807130848636]
# Discard ['1', '6', '4', '2'] [LB: 22.050807130848636] because lb=22.050807130848636 >= 21.746419713270026
# ======= Iteration 90 =======
# Current best tour: ['1', '6', '5', '4', '3', '2'] Length: 21.746419713270026
# Treat problem ['1', '6', '4', '5'] [LB: 18.800791901987974]
# --> Branch
# List of problems to treat:
# 	['1'] [LB: 17.215059123497515]
# 	['1', '2'] [LB: 17.314092579818546]
# 	['1', '5'] [LB: 21.0029496864565]
# 	['1', '6'] [LB: 18.593608197898767]
# 	['1', '6', '3'] [LB: 18.593608197898767]
# 	['1', '6', '4'] [LB: 18.800791901987974]
# 	['1', '6', '4', '3'] [LB: 21.445147266592596]
# 	['1', '6', '4', '5'] [LB: 18.800791901987974]
# 	['1', '6', '4', '5', '3'] [LB: 21.89761002835996]
# 	['1', '6', '4', '5', '2'] [LB: 22.61469879590254]
# Discard ['1', '6', '4', '5', '3'] [LB: 21.89761002835996] because lb=21.89761002835996 >= 21.746419713270026
# Discard ['1', '6', '4', '5', '2'] [LB: 22.61469879590254] because lb=22.61469879590254 >= 21.746419713270026
# ======= Iteration 93 =======
# Current best tour: ['1', '6', '5', '4', '3', '2'] Length: 21.746419713270026
# Treat problem ['1', '6', '4', '5'] [LB: 18.800791901987974]
# --> Optimal solution of ['1', '6', '4', '5'] (Opt: inf): None
# List of problems to treat:
# 	['1'] [LB: 17.215059123497515]
# 	['1', '2'] [LB: 17.314092579818546]
# 	['1', '5'] [LB: 21.0029496864565]
# 	['1', '6'] [LB: 18.593608197898767]
# 	['1', '6', '3'] [LB: 18.593608197898767]
# 	['1', '6', '4'] [LB: 18.800791901987974]
# 	['1', '6', '4', '3'] [LB: 21.445147266592596]
# ======= Iteration 94 =======
# Current best tour: ['1', '6', '5', '4', '3', '2'] Length: 21.746419713270026
# Treat problem ['1', '6', '4', '3'] [LB: 21.445147266592596]
# --> Branch
# List of problems to treat:
# 	['1'] [LB: 17.215059123497515]
# 	['1', '2'] [LB: 17.314092579818546]
# 	['1', '5'] [LB: 21.0029496864565]
# 	['1', '6'] [LB: 18.593608197898767]
# 	['1', '6', '3'] [LB: 18.593608197898767]
# 	['1', '6', '4'] [LB: 18.800791901987974]
# 	['1', '6', '4', '3'] [LB: 21.445147266592596]
# 	['1', '6', '4', '3', '5'] [LB: 25.087413411165272]
# 	['1', '6', '4', '3', '2'] [LB: 21.445147266592596]
# Discard ['1', '6', '4', '3', '5'] [LB: 25.087413411165272] because lb=25.087413411165272 >= 21.746419713270026
# ======= Iteration 95 =======
# Current best tour: ['1', '6', '5', '4', '3', '2'] Length: 21.746419713270026
# Treat problem ['1', '6', '4', '3', '2'] [LB: 21.445147266592596]
# --> Optimal solution of ['1', '6', '4', '3', '2'] (Opt: 29.76128176504873): ['1', '6', '4', '3', '2', '5']
# List of problems to treat:
# 	['1'] [LB: 17.215059123497515]
# 	['1', '2'] [LB: 17.314092579818546]
# 	['1', '5'] [LB: 21.0029496864565]
# 	['1', '6'] [LB: 18.593608197898767]
# 	['1', '6', '3'] [LB: 18.593608197898767]
# 	['1', '6', '4'] [LB: 18.800791901987974]
# 	['1', '6', '4', '3'] [LB: 21.445147266592596]
# ======= Iteration 97 =======
# Current best tour: ['1', '6', '5', '4', '3', '2'] Length: 21.746419713270026
# Treat problem ['1', '6', '4', '3'] [LB: 21.445147266592596]
# --> Optimal solution of ['1', '6', '4', '3'] (Opt: 29.76128176504873): ['1', '6', '4', '3', '2', '5']
# List of problems to treat:
# 	['1'] [LB: 17.215059123497515]
# 	['1', '2'] [LB: 17.314092579818546]
# 	['1', '5'] [LB: 21.0029496864565]
# 	['1', '6'] [LB: 18.593608197898767]
# 	['1', '6', '3'] [LB: 18.593608197898767]
# 	['1', '6', '4'] [LB: 18.800791901987974]
# ======= Iteration 98 =======
# Current best tour: ['1', '6', '5', '4', '3', '2'] Length: 21.746419713270026
# Treat problem ['1', '6', '4'] [LB: 18.800791901987974]
# --> Optimal solution of ['1', '6', '4'] (Opt: 29.76128176504873): ['1', '6', '4', '3', '2', '5']
# List of problems to treat:
# 	['1'] [LB: 17.215059123497515]
# 	['1', '2'] [LB: 17.314092579818546]
# 	['1', '5'] [LB: 21.0029496864565]
# 	['1', '6'] [LB: 18.593608197898767]
# 	['1', '6', '3'] [LB: 18.593608197898767]
# ======= Iteration 99 =======
# Current best tour: ['1', '6', '5', '4', '3', '2'] Length: 21.746419713270026
# Treat problem ['1', '6', '3'] [LB: 18.593608197898767]
# --> Branch
# List of problems to treat:
# 	['1'] [LB: 17.215059123497515]
# ...
# Current best tour: ['1', '6', '5', '4', '3', '2'] Length: 21.746419713270026
# Treat problem ['1', '5', '4', '6'] [LB: 21.0029496864565]
# --> Branch
# List of problems to treat:
# 	['1'] [LB: 17.215059123497515]
# 	['1', '2'] [LB: 17.314092579818546]
# 	['1', '5'] [LB: 21.0029496864565]
# 	['1', '5', '4'] [LB: 21.0029496864565]
# 	['1', '5', '4', '6'] [LB: 21.0029496864565]
# 	['1', '5', '4', '6', '3'] [LB: 21.0029496864565]
# 	['1', '5', '4', '6', '2'] [LB: 21.720387811790943]
# ======= Iteration 118 =======
# Current best tour: ['1', '6', '5', '4', '3', '2'] Length: 21.746419713270026
# Treat problem ['1', '5', '4', '6', '2'] [LB: 21.720387811790943]
# --> Optimal solution of ['1', '5', '4', '6', '2'] (Opt: 22.440530235794878): ['1', '5', '4', '6', '2', '3']
# List of problems to treat:
# 	['1'] [LB: 17.215059123497515]
# 	['1', '2'] [LB: 17.314092579818546]
# 	['1', '5'] [LB: 21.0029496864565]
# 	['1', '5', '4'] [LB: 21.0029496864565]
# 	['1', '5', '4', '6'] [LB: 21.0029496864565]
# 	['1', '5', '4', '6', '3'] [LB: 21.0029496864565]
# ======= Iteration 119 =======
# Current best tour: ['1', '6', '5', '4', '3', '2'] Length: 21.746419713270026
# Treat problem ['1', '5', '4', '6', '3'] [LB: 21.0029496864565]
# --> Optimal solution of ['1', '5', '4', '6', '3'] (Opt: 21.19831230042907): ['1', '5', '4', '6', '3', '2']
# List of problems to treat:
# 	['1'] [LB: 17.215059123497515]
# 	['1', '2'] [LB: 17.314092579818546]
# 	['1', '5'] [LB: 21.0029496864565]
# 	['1', '5', '4'] [LB: 21.0029496864565]
# 	['1', '5', '4', '6'] [LB: 21.0029496864565]
# ======= Iteration 120 =======
# Current best tour: ['1', '5', '4', '6', '3', '2'] Length: 21.19831230042907
# Treat problem ['1', '5', '4', '6'] [LB: 21.0029496864565]
# --> Optimal solution of ['1', '5', '4', '6'] (Opt: 21.19831230042907): ['1', '5', '4', '6', '3', '2']
# List of problems to treat:
# 	['1'] [LB: 17.215059123497515]
# 	['1', '2'] [LB: 17.314092579818546]
# 	['1', '5'] [LB: 21.0029496864565]
# 	['1', '5', '4'] [LB: 21.0029496864565]
# ======= Iteration 121 =======
# Current best tour: ['1', '5', '4', '6', '3', '2'] Length: 21.19831230042907
# Treat problem ['1', '5', '4'] [LB: 21.0029496864565]
# --> Optimal solution of ['1', '5', '4'] (Opt: 21.19831230042907): ['1', '5', '4', '6', '3', '2']
# List of problems to treat:
# 	['1'] [LB: 17.215059123497515]
# 	['1', '2'] [LB: 17.314092579818546]
# 	['1', '5'] [LB: 21.0029496864565]
# ======= Iteration 123 =======
# Current best tour: ['1', '5', '4', '6', '3', '2'] Length: 21.19831230042907
# Treat problem ['1', '5'] [LB: 21.0029496864565]
# --> Optimal solution of ['1', '5'] (Opt: 21.19831230042907): ['1', '5', '4', '6', '3', '2']
# List of problems to treat:
# 	['1'] [LB: 17.215059123497515]
# 	['1', '2'] [LB: 17.314092579818546]
# ======= Iteration 124 =======
# Current best tour: ['1', '5', '4', '6', '3', '2'] Length: 21.19831230042907
# Treat problem ['1', '2'] [LB: 17.314092579818546]
# --> Branch
# List of problems to treat:
# 	['1'] [LB: 17.215059123497515]
# 	['1', '2'] [LB: 17.314092579818546]
# 	['1', '2', '6'] [LB: 19.08723314459892]
# 	['1', '2', '4'] [LB: 21.57094492660125]
# 	['1', '2', '3'] [LB: 17.314092579818546]
# 	['1', '2', '5'] [LB: 22.390885617268243]
# Discard ['1', '2', '4'] [LB: 21.57094492660125] because lb=21.57094492660125 >= 21.19831230042907
# Discard ['1', '2', '5'] [LB: 22.390885617268243] because lb=22.390885617268243 >= 21.19831230042907
# ======= Iteration 126 =======
# Current best tour: ['1', '5', '4', '6', '3', '2'] Length: 21.19831230042907
# Treat problem ['1', '2', '3'] [LB: 17.314092579818546]
# --> Branch
# List of problems to treat:
# 	['1'] [LB: 17.215059123497515]
# 	['1', '2'] [LB: 17.314092579818546]
# 	['1', '2', '6'] [LB: 19.08723314459892]
# 	['1', '2', '3'] [LB: 17.314092579818546]
# 	['1', '2', '3', '6'] [LB: 17.314092579818546]
# 	['1', '2', '3', '4'] [LB: 19.702398918810072]
# 	['1', '2', '3', '5'] [LB: 20.410910706190528]
# ======= Iteration 127 =======
# Current best tour: ['1', '5', '4', '6', '3', '2'] Length: 21.19831230042907
# Treat problem ['1', '2', '3', '5'] [LB: 20.410910706190528]
# --> Branch
# List of problems to treat:
# 	['1'] [LB: 17.215059123497515]
# 	['1', '2'] [LB: 17.314092579818546]
# 	['1', '2', '6'] [LB: 19.08723314459892]
# 	['1', '2', '3'] [LB: 17.314092579818546]
# 	['1', '2', '3', '6'] [LB: 17.314092579818546]
# 	['1', '2', '3', '4'] [LB: 19.702398918810072]
# 	['1', '2', '3', '5'] [LB: 20.410910706190528]
# 	['1', '2', '3', '5', '6'] [LB: 21.39087744843952]
# 	['1', '2', '3', '5', '4'] [LB: 20.410910706190528]
# Discard ['1', '2', '3', '5', '6'] [LB: 21.39087744843952] because lb=21.39087744843952 >= 21.19831230042907
# ======= Iteration 128 =======
# Current best tour: ['1', '5', '4', '6', '3', '2'] Length: 21.19831230042907
# Treat problem ['1', '2', '3', '5', '4'] [LB: 20.410910706190528]
# --> Optimal solution of ['1', '2', '3', '5', '4'] (Opt: 22.092972642332533): ['1', '2', '3', '5', '4', '6']
# List of problems to treat:
# 	['1'] [LB: 17.215059123497515]
# 	['1', '2'] [LB: 17.314092579818546]
# 	['1', '2', '6'] [LB: 19.08723314459892]
# 	['1', '2', '3'] [LB: 17.314092579818546]
# 	['1', '2', '3', '6'] [LB: 17.314092579818546]
# 	['1', '2', '3', '4'] [LB: 19.702398918810072]
# 	['1', '2', '3', '5'] [LB: 20.410910706190528]
# ======= Iteration 130 =======
# Current best tour: ['1', '5', '4', '6', '3', '2'] Length: 21.19831230042907
# Treat problem ['1', '2', '3', '5'] [LB: 20.410910706190528]
# --> Optimal solution of ['1', '2', '3', '5'] (Opt: 22.092972642332533): ['1', '2', '3', '5', '4', '6']
# List of problems to treat:
# 	['1'] [LB: 17.215059123497515]
# 	['1', '2'] [LB: 17.314092579818546]
# 	['1', '2', '6'] [LB: 19.08723314459892]
# 	['1', '2', '3'] [LB: 17.314092579818546]
# 	['1', '2', '3', '6'] [LB: 17.314092579818546]
# 	['1', '2', '3', '4'] [LB: 19.702398918810072]
# ======= Iteration 131 =======
# Current best tour: ['1', '5', '4', '6', '3', '2'] Length: 21.19831230042907
# Treat problem ['1', '2', '3', '4'] [LB: 19.702398918810072]
# --> Branch
# List of problems to treat:
# 	['1'] [LB: 17.215059123497515]
# 	['1', '2'] [LB: 17.314092579818546]
# 	['1', '2', '6'] [LB: 19.08723314459892]
# 	['1', '2', '3'] [LB: 17.314092579818546]
# 	['1', '2', '3', '6'] [LB: 17.314092579818546]
# 	['1', '2', '3', '4'] [LB: 19.702398918810072]
# 	['1', '2', '3', '4', '6'] [LB: 19.958447944423167]
# 	['1', '2', '3', '4', '5'] [LB: 19.702398918810072]
# ======= Iteration 132 =======
# Current best tour: ['1', '5', '4', '6', '3', '2'] Length: 21.19831230042907
# Treat problem ['1', '2', '3', '4', '5'] [LB: 19.702398918810072]
# --> Optimal solution of ['1', '2', '3', '4', '5'] (Opt: 21.746419713270022): ['1', '2', '3', '4', '5', '6']
# List of problems to treat:
# 	['1'] [LB: 17.215059123497515]
# 	['1', '2'] [LB: 17.314092579818546]
# 	['1', '2', '6'] [LB: 19.08723314459892]
# 	['1', '2', '3'] [LB: 17.314092579818546]
# 	['1', '2', '3', '6'] [LB: 17.314092579818546]
# 	['1', '2', '3', '4'] [LB: 19.702398918810072]
# 	['1', '2', '3', '4', '6'] [LB: 19.958447944423167]
# ======= Iteration 133 =======
# Current best tour: ['1', '5', '4', '6', '3', '2'] Length: 21.19831230042907
# Treat problem ['1', '2', '3', '4', '6'] [LB: 19.958447944423167]
# --> Optimal solution of ['1', '2', '3', '4', '6'] (Opt: 25.029818111371892): ['1', '2', '3', '4', '6', '5']
# List of problems to treat:
# 	['1'] [LB: 17.215059123497515]
# 	['1', '2'] [LB: 17.314092579818546]
# 	['1', '2', '6'] [LB: 19.08723314459892]
# 	['1', '2', '3'] [LB: 17.314092579818546]
# 	['1', '2', '3', '6'] [LB: 17.314092579818546]
# 	['1', '2', '3', '4'] [LB: 19.702398918810072]
# ======= Iteration 134 =======
# Current best tour: ['1', '5', '4', '6', '3', '2'] Length: 21.19831230042907
# Treat problem ['1', '2', '3', '4'] [LB: 19.702398918810072]
# --> Optimal solution of ['1', '2', '3', '4'] (Opt: 21.746419713270022): ['1', '2', '3', '4', '5', '6']
# List of problems to treat:
# 	['1'] [LB: 17.215059123497515]
# 	['1', '2'] [LB: 17.314092579818546]
# 	['1', '2', '6'] [LB: 19.08723314459892]
# 	['1', '2', '3'] [LB: 17.314092579818546]
# 	['1', '2', '3', '6'] [LB: 17.314092579818546]
# ======= Iteration 135 =======
# Current best tour: ['1', '5', '4', '6', '3', '2'] Length: 21.19831230042907
# Treat problem ['1', '2', '3', '6'] [LB: 17.314092579818546]
# --> Branch
# List of problems to treat:
# 	['1'] [LB: 17.215059123497515]
# 	['1', '2'] [LB: 17.314092579818546]
# 	['1', '2', '6'] [LB: 19.08723314459892]
# 	['1', '2', '3'] [LB: 17.314092579818546]
# 	['1', '2', '3', '6'] [LB: 17.314092579818546]
# 	['1', '2', '3', '6', '4'] [LB: 17.314092579818546]
# 	['1', '2', '3', '6', '5'] [LB: 17.676051438136497]
# ======= Iteration 136 =======
# Current best tour: ['1', '5', '4', '6', '3', '2'] Length: 21.19831230042907
# Treat problem ['1', '2', '3', '6', '5'] [LB: 17.676051438136497]
# --> Optimal solution of ['1', '2', '3', '6', '5'] (Opt: 22.052544133880314): ['1', '2', '3', '6', '5', '4']
# List of problems to treat:
# 	['1'] [LB: 17.215059123497515]
# 	['1', '2'] [LB: 17.314092579818546]
# 	['1', '2', '6'] [LB: 19.08723314459892]
# 	['1', '2', '3'] [LB: 17.314092579818546]
# 	['1', '2', '3', '6'] [LB: 17.314092579818546]
# 	['1', '2', '3', '6', '4'] [LB: 17.314092579818546]
# ======= Iteration 137 =======
# Current best tour: ['1', '5', '4', '6', '3', '2'] Length: 21.19831230042907
# Treat problem ['1', '2', '3', '6', '4'] [LB: 17.314092579818546]
# --> Optimal solution of ['1', '2', '3', '6', '4'] (Opt: 21.198312300429073): ['1', '2', '3', '6', '4', '5']
# List of problems to treat:
# 	['1'] [LB: 17.215059123497515]
# 	['1', '2'] [LB: 17.314092579818546]
# 	['1', '2', '6'] [LB: 19.08723314459892]
# 	['1', '2', '3'] [LB: 17.314092579818546]
# 	['1', '2', '3', '6'] [LB: 17.314092579818546]
# ======= Iteration 138 =======
# Current best tour: ['1', '5', '4', '6', '3', '2'] Length: 21.19831230042907
# Treat problem ['1', '2', '3', '6'] [LB: 17.314092579818546]
# --> Optimal solution of ['1', '2', '3', '6'] (Opt: 21.198312300429073): ['1', '2', '3', '6', '4', '5']
# List of problems to treat:
# 	['1'] [LB: 17.215059123497515]
# 	['1', '2'] [LB: 17.314092579818546]
# 	['1', '2', '6'] [LB: 19.08723314459892]
# 	['1', '2', '3'] [LB: 17.314092579818546]
# ======= Iteration 139 =======
# Current best tour: ['1', '5', '4', '6', '3', '2'] Length: 21.19831230042907
# Treat problem ['1', '2', '3'] [LB: 17.314092579818546]
# --> Optimal solution of ['1', '2', '3'] (Opt: 21.198312300429073): ['1', '2', '3', '6', '4', '5']
# List of problems to treat:
# 	['1'] [LB: 17.215059123497515]
# 	['1', '2'] [LB: 17.314092579818546]
# 	['1', '2', '6'] [LB: 19.08723314459892]
# ======= Iteration 141 =======
# Current best tour: ['1', '5', '4', '6', '3', '2'] Length: 21.19831230042907
# Treat problem ['1', '2', '6'] [LB: 19.08723314459892]
# --> Branch
# List of problems to treat:
# 	['1'] [LB: 17.215059123497515]
# 	['1', '2'] [LB: 17.314092579818546]
# 	['1', '2', '6'] [LB: 19.08723314459892]
# 	['1', '2', '6', '3'] [LB: 19.08723314459892]
# 	['1', '2', '6', '4'] [LB: 19.294416848688126]
# 	['1', '2', '6', '5'] [LB: 19.656375707006074]
# ======= Iteration 142 =======
# Current best tour: ['1', '5', '4', '6', '3', '2'] Length: 21.19831230042907
# Treat problem ['1', '2', '6', '5'] [LB: 19.656375707006074]
# --> Branch
# List of problems to treat:
# 	['1'] [LB: 17.215059123497515]
# 	['1', '2'] [LB: 17.314092579818546]
# 	['1', '2', '6'] [LB: 19.08723314459892]
# 	['1', '2', '6', '3'] [LB: 19.08723314459892]
# 	['1', '2', '6', '4'] [LB: 19.294416848688126]
# 	['1', '2', '6', '5'] [LB: 19.656375707006074]
# 	['1', '2', '6', '5', '3'] [LB: 23.3712017173091]
# 	['1', '2', '6', '5', '4'] [LB: 19.656375707006074]
# Discard ['1', '2', '6', '5', '3'] [LB: 23.3712017173091] because lb=23.3712017173091 >= 21.19831230042907
# ======= Iteration 143 =======
# Current best tour: ['1', '5', '4', '6', '3', '2'] Length: 21.19831230042907
# Treat problem ['1', '2', '6', '5', '4'] [LB: 19.656375707006074]
# --> Optimal solution of ['1', '2', '6', '5', '4'] (Opt: 23.310272488202227): ['1', '2', '6', '5', '4', '3']
# List of problems to treat:
# 	['1'] [LB: 17.215059123497515]
# 	['1', '2'] [LB: 17.314092579818546]
# 	['1', '2', '6'] [LB: 19.08723314459892]
# 	['1', '2', '6', '3'] [LB: 19.08723314459892]
# 	['1', '2', '6', '4'] [LB: 19.294416848688126]
# 	['1', '2', '6', '5'] [LB: 19.656375707006074]
# ======= Iteration 145 =======
# Current best tour: ['1', '5', '4', '6', '3', '2'] Length: 21.19831230042907
# Treat problem ['1', '2', '6', '5'] [LB: 19.656375707006074]
# --> Optimal solution of ['1', '2', '6', '5'] (Opt: 23.310272488202227): ['1', '2', '6', '5', '4', '3']
# List of problems to treat:
# 	['1'] [LB: 17.215059123497515]
# 	['1', '2'] [LB: 17.314092579818546]
# 	['1', '2', '6'] [LB: 19.08723314459892]
# 	['1', '2', '6', '3'] [LB: 19.08723314459892]
# 	['1', '2', '6', '4'] [LB: 19.294416848688126]
# ======= Iteration 146 =======
# Current best tour: ['1', '5', '4', '6', '3', '2'] Length: 21.19831230042907
# Treat problem ['1', '2', '6', '4'] [LB: 19.294416848688126]
# --> Branch
# List of problems to treat:
# 	['1'] [LB: 17.215059123497515]
# 	['1', '2'] [LB: 17.314092579818546]
# 	['1', '2', '6'] [LB: 19.08723314459892]
# 	['1', '2', '6', '3'] [LB: 19.08723314459892]
# 	['1', '2', '6', '4'] [LB: 19.294416848688126]
# 	['1', '2', '6', '4', '3'] [LB: 21.938772213292744]
# 	['1', '2', '6', '4', '5'] [LB: 19.294416848688126]
# Discard ['1', '2', '6', '4', '3'] [LB: 21.938772213292744] because lb=21.938772213292744 >= 21.19831230042907
# ======= Iteration 147 =======
# Current best tour: ['1', '5', '4', '6', '3', '2'] Length: 21.19831230042907
# Treat problem ['1', '2', '6', '4', '5'] [LB: 19.294416848688126]
# --> Optimal solution of ['1', '2', '6', '4', '5'] (Opt: 23.656825417264734): ['1', '2', '6', '4', '5', '3']
# List of problems to treat:
# 	['1'] [LB: 17.215059123497515]
# 	['1', '2'] [LB: 17.314092579818546]
# 	['1', '2', '6'] [LB: 19.08723314459892]
# 	['1', '2', '6', '3'] [LB: 19.08723314459892]
# 	['1', '2', '6', '4'] [LB: 19.294416848688126]
# ======= Iteration 149 =======
# Current best tour: ['1', '5', '4', '6', '3', '2'] Length: 21.19831230042907
# Treat problem ['1', '2', '6', '4'] [LB: 19.294416848688126]
# --> Optimal solution of ['1', '2', '6', '4'] (Opt: 23.656825417264734): ['1', '2', '6', '4', '5', '3']
# List of problems to treat:
# 	['1'] [LB: 17.215059123497515]
# 	['1', '2'] [LB: 17.314092579818546]
# 	['1', '2', '6'] [LB: 19.08723314459892]
# 	['1', '2', '6', '3'] [LB: 19.08723314459892]
# ======= Iteration 150 =======
# Current best tour: ['1', '5', '4', '6', '3', '2'] Length: 21.19831230042907
# Treat problem ['1', '2', '6', '3'] [LB: 19.08723314459892]
# --> Branch
# List of problems to treat:
# 	['1'] [LB: 17.215059123497515]
# 	['1', '2'] [LB: 17.314092579818546]
# 	['1', '2', '6'] [LB: 19.08723314459892]
# 	['1', '2', '6', '3'] [LB: 19.08723314459892]
# 	['1', '2', '6', '3', '4'] [LB: 22.020987501791137]
# 	['1', '2', '6', '3', '5'] [LB: 22.729499289171592]
# Discard ['1', '2', '6', '3', '4'] [LB: 22.020987501791137] because lb=22.020987501791137 >= 21.19831230042907
# Discard ['1', '2', '6', '3', '5'] [LB: 22.729499289171592] because lb=22.729499289171592 >= 21.19831230042907
# ======= Iteration 153 =======
# Current best tour: ['1', '5', '4', '6', '3', '2'] Length: 21.19831230042907
# Treat problem ['1', '2', '6', '3'] [LB: 19.08723314459892]
# --> Optimal solution of ['1', '2', '6', '3'] (Opt: inf): None
# List of problems to treat:
# 	['1'] [LB: 17.215059123497515]
# 	['1', '2'] [LB: 17.314092579818546]
# 	['1', '2', '6'] [LB: 19.08723314459892]
# ======= Iteration 154 =======
# Current best tour: ['1', '5', '4', '6', '3', '2'] Length: 21.19831230042907
# Treat problem ['1', '2', '6'] [LB: 19.08723314459892]
# --> Optimal solution of ['1', '2', '6'] (Opt: 23.310272488202227): ['1', '2', '6', '5', '4', '3']
# List of problems to treat:
# 	['1'] [LB: 17.215059123497515]
# 	['1', '2'] [LB: 17.314092579818546]
# ======= Iteration 155 =======
# Current best tour: ['1', '5', '4', '6', '3', '2'] Length: 21.19831230042907
# Treat problem ['1', '2'] [LB: 17.314092579818546]
# --> Optimal solution of ['1', '2'] (Opt: 21.198312300429073): ['1', '2', '3', '6', '4', '5']
# List of problems to treat:
# 	['1'] [LB: 17.215059123497515]
# ======= Iteration 156 =======
# Current best tour: ['1', '5', '4', '6', '3', '2'] Length: 21.19831230042907
# Treat problem ['1'] [LB: 17.215059123497515]
# --> Optimal solution of ['1'] (Opt: 21.19831230042907): ['1', '5', '4', '6', '3', '2']
# No more problem to treat.

# %%
print(f'Optimal tour: {fullProblem.optimalTour}')
print(f'Length of the optimal tour: {fullProblem.optimalValue}')
# Out:
# Optimal tour: ['1', '5', '4', '6', '3', '2']
# Length of the optimal tour: 21.19831230042907

# %%
# %matplotlib inline
fig, ax = plt.subplots()
ax.scatter(x, y)
for i in range(n):
    ax.annotate(names[i], (x[i], y[i]))
for i in range(len(fullProblem.optimalTour) - 1):
    j1 = names.index(fullProblem.optimalTour[i])
    j2 = names.index(fullProblem.optimalTour[i + 1])
    ax.plot([x[j1], x[j2]], [y[j1], y[j2]], 'ro-')
j1 = names.index(fullProblem.optimalTour[-1])
j2 = names.index(fullProblem.optimalTour[0])
p = ax.plot([x[j1], x[j2]], [y[j1], y[j2]], 'ro-')
