# %% [markdown]
# #Applying Linear PCA, Kernel PCA (with Gaussian Kernel) and Isomaps for dimensionality reduction on a few datasets in Python

# %% [markdown]
# In this article, the **linear PCA**, the **kernel PCA** and the **Isomap** algorithms will be applied on a few datasets, to show whether the structure of the data in higher dimensions are preserved in the lower dimension or not for the methods. The scikit learn implementations will be used.

# %% [markdown]
# The following description of the problem is taken from the course:
#
# For Isomap, the original dataset from Joshua Tenenbaum, the primary creator of the isometric feature mapping algorithm, will be used (as given in one of the assignments of the **Edx Course Microsoft: DAT210x Programming with Python for Data Science**, by replicating his canonical, dimensionality reduction research experiment for visual perception). It consists of 698 samples of 4096-dimensional vectors. These vectors are the coded brightness values of 64x64-pixel heads that have been rendered facing various directions and lighted from many angles.
#
# For this assignment, Dr. Tenenbaum's experiment will be replicated by:
#
# 1. Applying both PCA and Isomap to the 698 raw images to derive 2D principal components and a 2D embedding of the data's intrinsic geometric structure.
# 2. Projecting both onto a 2D scatter plot, with a few superimposed face images on the associated samples.
# 3. Increasing n_components to three and plotting.

# %% [markdown]
# The following figure shows first 100 images from the dataset.

# %%
#ipython nbconvert pcaiso.ipynb
# %matplotlib inline

from IPython.display import HTML

HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
<form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>

# %%
from IPython.display import Image
Image(filename='C:\\courses\\Edx\\Past\\Microsoft\\Microsoft DAT210x Programming with Python for Data Science\\Week4\\Assignments\\heads.png', width=800, height=800)

# %% [markdown]
# # Applying Principal Component Analysis (PCA)
#
# Now let's apply **PCA** on the dataset and choose the first 3 principal components. If we project the data onto these components, to obtain the following plots. Notice that with only 3 principal components chosen, the projected images approximate the original images quite well.

# %%
Image(filename='C:\\courses\\Edx\\Past\\Microsoft\\Microsoft DAT210x Programming with Python for Data Science\\Week4\\Assignments\\heads_pca_1.png', width=800, height=800)

# %%
Image(filename='C:\\courses\\Edx\\Past\\Microsoft\\Microsoft DAT210x Programming with Python for Data Science\\Week4\\Assignments\\heads_pca_2.png', width=800, height=800)

# %%
Image(filename='C:\\courses\\Edx\\Past\\Microsoft\\Microsoft DAT210x Programming with Python for Data Science\\Week4\\Assignments\\heads_pca_3.png', width=800, height=800)

# %%
Image(filename='C:\\courses\\Edx\\Past\\Microsoft\\Microsoft DAT210x Programming with Python for Data Science\\Week4\\Assignments\\heads_pca.png', width=800, height=1200)

# %% [markdown]
# # Applying Principal Component Analysis (PCA)
#
# Now let's apply **KPCA** on the dataset (with ***Gaussian Kernel*) and choose only the first 3 principal components. If we project the data onto these components, to obtain the following plots. Notice that with only 3 principal components chosen, the projected images approximate the original images quite well.

# %%
Image(filename='C:\\courses\\Edx\\Past\\Microsoft\\Microsoft DAT210x Programming with Python for Data Science\\Week4\\Assignments\\heads_kpca_1.png', width=800, height=800)

# %%
Image(filename='C:\\courses\\Edx\\Past\\Microsoft\\Microsoft DAT210x Programming with Python for Data Science\\Week4\\Assignments\\heads_kpca_2.png', width=800, height=800)

# %%
Image(filename='C:\\courses\\Edx\\Past\\Microsoft\\Microsoft DAT210x Programming with Python for Data Science\\Week4\\Assignments\\heads_kpca_3.png', width=800, height=800)

# %%
Image(filename='C:\\courses\\Edx\\Past\\Microsoft\\Microsoft DAT210x Programming with Python for Data Science\\Week4\\Assignments\\heads_kpca.png', width=800, height=1200)

# %% [markdown]
# # Applying Isomap
#
# Now let's apply **Isomap** on the same dataset with 8 nearest neighbors and choose only the first 3 **manifolds**. If we project the data onto these components, to obtain the following plots. Notice that with only 3 **manifolds** chosen, the projected images approximate the original images quite well.

# %%
Image(filename='C:\\courses\\Edx\\Past\\Microsoft\\Microsoft DAT210x Programming with Python for Data Science\\Week4\\Assignments\\heads_iso_1.png', width=800, height=800)

# %%
Image(filename='C:\\courses\\Edx\\Past\\Microsoft\\Microsoft DAT210x Programming with Python for Data Science\\Week4\\Assignments\\heads_iso_2.png', width=800, height=800)

# %%
Image(filename='C:\\courses\\Edx\\Past\\Microsoft\\Microsoft DAT210x Programming with Python for Data Science\\Week4\\Assignments\\heads_iso_3.png', width=800, height=800)

# %%
Image(filename='C:\\courses\\Edx\\Past\\Microsoft\\Microsoft DAT210x Programming with Python for Data Science\\Week4\\Assignments\\heads_iso.png', width=800, height=1200)

# %% [markdown]
# As can be seen from the above results, between **linear PCA**, **Kernel PCA** and the **non-linear Isomap**, the **Isomap** algorithm is better able to capture the true nature of the faces dataset when reduced to two component.

# %% [markdown]
# Each coordinate axis of the **3D manifold** correlates highly with **one degree of freedom** from the original, underlying data (e.g., Left, Right, Down, Up Head Positions).
