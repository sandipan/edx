# %% [markdown]
# #Using Uninformed & Informed Search Algorithms to Solve 8-Puzzle

# %% [markdown]
# This problem appeared as a project in the *edX course ColumbiaX: CSMM.101x Artificial Intelligence (AI)*. In this assignment an agent will be implemented to solve the 8-puzzle game (and the game generalized to an n × n array).

# %% [markdown]
# The following description of the problem is taken from the course:
#
# ##I. Introduction
#
# An instance of the **n-puzzle game** consists of a board holding $n^2 − 1$ distinct movable tiles, plus an empty space. The tiles are numbers from the set ${1, …, n^2 − 1}$. For any such board, the empty space may be legally swapped with any tile horizontally or vertically adjacent to it. In this assignment, the blank space is going to be represented with the number 0.
# Given an initial state of the board, the combinatorial search problem is to find a sequence of moves that transitions this state to the goal state; that is, the configuration with all tiles arranged in ascending order $⟨0, 1, …, n^2 − 1⟩$. The search space is the set of all possible states reachable from the initial state.
# The blank space may be swapped with a component in one of the four directions *{‘Up’, ‘Down’, ‘Left’, ‘Right’}*, one move at a time. The cost of moving from one configuration of the board to another is the same and equal to one. Thus, the total cost of path is equal to the number of moves made from the initial state to the goal state.

# %% [markdown]
# ##II. Algorithm Review
#
# The searches begin by visiting the root node of the search tree, given by the initial state. Among other book-keeping details, three major things happen in sequence in order to visit a node:
#
# 1. First, we remove a node from the frontier set.
# 2. Second, we check the state against the goal state to determine if a solution has been found.
# 3. Finally, if the result of the check is negative, we then expand the node. To expand a given node, we generate successor nodes adjacent to the current node, and add them to the frontier set. Note that if these successor nodes are already in the frontier, or have already been visited, then they should not be added to the frontier again.
#
# This describes the life-cycle of a visit, and is the basic order of operations for search agents in this assignment—(1) remove, (2) check, and (3) expand. In this assignment, we will implement algorithms as described here.

# %% [markdown]
# ##III. What The Program Need to Output
#
# ####Example: Breadth-First Search
#
# Suppose the program is executed for breadth-first search statring from the initial state *1,2,5,3,4,0,6,7,8* as follows:

# %%
from IPython.display import Image
Image(filename='C:\\courses\\Edx\\Current\\AI\\Week2\\im1.png',width=400,height=400)

# %% [markdown]
# The output file should contain exactly the following lines:
#
# path_to_goal: ['Up', 'Left', 'Left']
#
# cost_of_path: 3
#
# nodes_expanded: 10
#
# fringe_size: 11
#
# max_fringe_size: 12
#
# search_depth: 3
#
# max_search_depth: 4
#
# running_time: 0.00188088
#
# max_ram_usage: 0.07812500

# %%
#ipython nbconvert pcaiso.ipynb
# %matplotlib inline

from IPython.display import HTML

HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
<form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>

# %% [markdown]
# The following algorithms are going to be implemented and taken from the lecture slides from the same course.

# %%
from IPython.display import Image
Image(filename='C:\\courses\\Edx\\Current\\AI\\Week2\\im2.png')

# %%
from IPython.display import Image
Image(filename='C:\\courses\\Edx\\Current\\AI\\Week2\\im3.png')

# %% [markdown]
# ## Outputs
#
# The following figures and animations show how the 8-puzzle was solved starting from different initial states with different algorithms. Also, the figures display the search paths from starting state to the goal node (the states with red text denote the path chosen). Let's start with a very simple example.

# %% [markdown]
# #### Example 1: Initial State: 1,2,5,3,4,0,6,7,8
#
# (1) **BFS**

# %%
Image(filename='C:\\courses\\Edx\\Current\\AI\\Week2\\sol_b0.gif')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-d29e332d177d> in <module>()
# ----> 1 Image(filename='C:\\courses\\Edx\\Current\\AI\\Week2\\sol_b0.gif')
#
# C:\Users\Sandipan.Dey\Anaconda\envs\dato-env\lib\site-packages\IPython\core\display.pyc in __init__(self, data, url, filename, format, embed, width, height, retina, unconfined, metadata)
#     731
#     732         if self.embed and self.format not in self._ACCEPTABLE_EMBEDDINGS:
# --> 733             raise ValueError("Cannot embed the '%s' image format" % (self.format))
#     734         self.width = width
#     735         self.height = height
#
# ValueError: Cannot embed the 'gif' image format

# %%
Image(filename='C:\\courses\\Edx\\Current\\AI\\Week2\\b_b0.gv.png')

# %% [markdown]
# (2) **DFS**

# %%
Image(filename='C:\\courses\\Edx\\Current\\AI\\Week2\\sol_d0.gif')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-d29e332d177d> in <module>()
# ----> 1 Image(filename='C:\\courses\\Edx\\Current\\AI\\Week2\\sol_b0.gif')
#
# C:\Users\Sandipan.Dey\Anaconda\envs\dato-env\lib\site-packages\IPython\core\display.pyc in __init__(self, data, url, filename, format, embed, width, height, retina, unconfined, metadata)
#     731
#     732         if self.embed and self.format not in self._ACCEPTABLE_EMBEDDINGS:
# --> 733             raise ValueError("Cannot embed the '%s' image format" % (self.format))
#     734         self.width = width
#     735         self.height = height
#
# ValueError: Cannot embed the 'gif' image format

# %%
Image(filename='C:\\courses\\Edx\\Current\\AI\\Week2\\b_d0.gv.png')

# %% [markdown]
# (3) **A* **

# %%
Image(filename='C:\\courses\\Edx\\Current\\AI\\Week2\\sol_a0.gif')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-596e2025e6ad> in <module>()
# ----> 1 Image(filename='C:\\courses\\Edx\\Current\\AI\\Week2\\sol_a0.gif')
#
# C:\Users\Sandipan.Dey\Anaconda\envs\dato-env\lib\site-packages\IPython\core\display.pyc in __init__(self, data, url, filename, format, embed, width, height, retina, unconfined, metadata)
#     731
#     732         if self.embed and self.format not in self._ACCEPTABLE_EMBEDDINGS:
# --> 733             raise ValueError("Cannot embed the '%s' image format" % (self.format))
#     734         self.width = width
#     735         self.height = height
#
# ValueError: Cannot embed the 'gif' image format

# %%
Image(filename='C:\\courses\\Edx\\Current\\AI\\Week2\\b_a0.gv.png')

# %% [markdown]
# (3) **ID-A* **

# %%
Image(filename='C:\\courses\\Edx\\Current\\AI\\Week2\\sol_i0.gif')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-7923756c53d5> in <module>()
# ----> 1 Image(filename='C:\\courses\\Edx\\Current\\AI\\Week2\\sol_i0.gif')
#
# C:\Users\Sandipan.Dey\Anaconda\envs\dato-env\lib\site-packages\IPython\core\display.pyc in __init__(self, data, url, filename, format, embed, width, height, retina, unconfined, metadata)
#     731
#     732         if self.embed and self.format not in self._ACCEPTABLE_EMBEDDINGS:
# --> 733             raise ValueError("Cannot embed the '%s' image format" % (self.format))
#     734         self.width = width
#     735         self.height = height
#
# ValueError: Cannot embed the 'gif' image format

# %%
Image(filename='C:\\courses\\Edx\\Current\\AI\\Week2\\b_i0.gv.png')

# %% [markdown]
# #### Example 2: Initial State: 1,0,2,7,5,4,8.6.3
#
# (1) **A* **

# %%
Image(filename='C:\\courses\\Edx\\Current\\AI\\Week2\\sol_a4.gif')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-d9741c75d22c> in <module>()
# ----> 1 Image(filename='C:\\courses\\Edx\\Current\\AI\\Week2\\sol_a4.gif')
#
# C:\Users\Sandipan.Dey\Anaconda\envs\dato-env\lib\site-packages\IPython\core\display.pyc in __init__(self, data, url, filename, format, embed, width, height, retina, unconfined, metadata)
#     731
#     732         if self.embed and self.format not in self._ACCEPTABLE_EMBEDDINGS:
# --> 733             raise ValueError("Cannot embed the '%s' image format" % (self.format))
#     734         self.width = width
#     735         self.height = height
#
# ValueError: Cannot embed the 'gif' image format

# %%
Image(filename='C:\\courses\\Edx\\Current\\AI\\Week2\\b_a4_1.gv.png')

# %%
Image(filename='C:\\courses\\Edx\\Current\\AI\\Week2\\b_a4_2.gv.png')

# %%
Image(filename='C:\\courses\\Edx\\Current\\AI\\Week2\\b_a4_3.gv.png')

# %% [markdown]
# (2) **ID-A* **

# %%
Image(filename='C:\\courses\\Edx\\Current\\AI\\Week2\\sol_i4.gif')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-4ebe5e0c3113> in <module>()
# ----> 1 Image(filename='C:\\courses\\Edx\\Current\\AI\\Week2\\sol_i4.gif')
#
# C:\Users\Sandipan.Dey\Anaconda\envs\dato-env\lib\site-packages\IPython\core\display.pyc in __init__(self, data, url, filename, format, embed, width, height, retina, unconfined, metadata)
#     731
#     732         if self.embed and self.format not in self._ACCEPTABLE_EMBEDDINGS:
# --> 733             raise ValueError("Cannot embed the '%s' image format" % (self.format))
#     734         self.width = width
#     735         self.height = height
#
# ValueError: Cannot embed the 'gif' image format

# %%
Image(filename='C:\\courses\\Edx\\Current\\AI\\Week2\\b_i4_1.gv.png')

# %%
Image(filename='C:\\courses\\Edx\\Current\\AI\\Week2\\b_a4_2.gv.png')

# %%
Image(filename='C:\\courses\\Edx\\Current\\AI\\Week2\\b_a4_3.gv.png')
