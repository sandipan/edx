# %% [markdown]
# #Implementing a k-class Bayes Classifier in Python

# %% [markdown]
# The following problems appeared as a project in the *edX course ColumbiaX: CSMM.102x Machine Learning*. The following problem description is taken from the course project itself.

# %%
#ipython nbconvert pcaiso.ipynb
# %matplotlib inline

from IPython.display import HTML

HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
<form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>

# %%
from IPython.display import Image
Image(filename='C:\\courses\\Edx\\Current\\ML\\Week6\\im1.png')

# %% [markdown]
# The following figure shows a first few rows of a sample training dataset with *K=5* class labels.

# %%
import pandas as pd
df = pd.read_csv('C:/courses/Edx/Current/ML/Week6/X_train1.csv', header=None, names=['x1', 'x2'])
df1 = pd.read_csv('C:/courses/Edx/Current/ML/Week6/y_train1.csv', header=None, names=['y'])
df['y'] = df1.y
df.head()
# Out:
#          x1        x2  y
# 0  5.731453  4.517417  4
# 1 -0.743516  2.157767  3
# 2  5.745734  1.205449  1
# 3 -0.322106 -0.183691  0
# 4  2.200057 -1.658819  3

# %% [markdown]
# The following figure shows how the **Bayesian Classifier** can be first trained to estimate the **Prior** and the **Class Conditional Gaussian Densities** (as a **Generative Model**) and then using **Bayes Rule** the **Posterior Probabilities** for the class labels can be predicted on the new test dataset.

# %%
from IPython.display import Image
Image(filename='C:\\courses\\Edx\\Current\\ML\\Week6\\f1.png', width=600, height=600)

# %% [markdown]
# The following figure shows the class conditional densities learnt from the training dataset with **MLE**.

# %%
Image(filename='C:\\courses\\Edx\\Current\\ML\\Week6\\ccd.png')

# %%
Image(filename='C:\\courses\\Edx\\Current\\ML\\Week6\\ccd3d.png')

# %% [markdown]
# The following figure shows the predicted posteriror probabilities on the test dataset.

# %%
Image(filename='C:\\courses\\Edx\\Current\\ML\\Week6\\probs.png')

# %% [markdown]
# The following figure shows the decision boundaries with the trained classifier on the same 2-D test dataset. As can be seen, since the the covariance matrices of the class conditional Gaussians were not shared (unlike as in the case of **Linear Discriminant Analysis**), the decision boundaries are quite complex.

# %%
Image(filename='C:\\courses\\Edx\\Current\\ML\\Week6\\b0.png')

# %% [markdown]
# The following figures show the decision boundaries learnt with the *Bayesian Classsfier* trained and tested on different sample datasets respectively.

# %%
Image(filename='C:\\courses\\Edx\\Current\\ML\\Week6\\b2.png')

# %%
Image(filename='C:\\courses\\Edx\\Current\\ML\\Week6\\b3.png')

# %%
Image(filename='C:\\courses\\Edx\\Current\\ML\\Week6\\b3.png')

# %%
Image(filename='C:\\courses\\Edx\\Current\\ML\\Week6\\b5.png')

# %%
Image(filename='C:\\courses\\Edx\\Current\\ML\\Week6\\b6.png')

# %%
Image(filename='C:\\courses\\Edx\\Current\\ML\\Week6\\b7.png')

# %%
Image(filename='C:\\courses\\Edx\\Current\\ML\\Week6\\b8.png')

# %%
Image(filename='C:\\courses\\Edx\\Current\\ML\\Week6\\b9.png')

# %%
Image(filename='C:\\courses\\Edx\\Current\\ML\\Week6\\b10.png')
